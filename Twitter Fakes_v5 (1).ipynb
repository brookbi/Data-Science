# %%
#Import everything#
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np

# %%
#Bring in the Datasets #
genuine_tweets = pd.read_csv("C:/Twitter/genuine_accounts/tweets.csv")
genuine_users = pd.read_csv("C:/Twitter/genuine_accounts/users.csv")
# Out:
# C:\Users\cct51\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sbot_tweets_1 = pd.read_csv("C:/Twitter/social_spambots_1/tweets.csv")
sbot_users_1 = pd.read_csv("C:/Twitter/social_spambots_1/users.csv")
sbot_tweets_2 = pd.read_csv("C:/Twitter/social_spambots_2/tweets.csv")
sbot_users_2 = pd.read_csv("C:/Twitter/social_spambots_2/users.csv")
sbot_tweets_3 = pd.read_csv("C:/Twitter/social_spambots_3/tweets.csv")
sbot_users_3 = pd.read_csv("C:/Twitter/social_spambots_3/users.csv")
ffollow_users = pd.read_csv("C:/Twitter/fake_followers/users.csv")
ffollow_tweets = pd.read_csv("C:/Twitter/fake_followers/tweets.csv")
# Out:
# C:\Users\cct51\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\cct51\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\cct51\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tbot_tweets = pd.read_csv("C:/Twitter/traditional_spambots_1/tweets.csv")
tbot_users_1 = pd.read_csv("C:/Twitter/traditional_spambots_1/users.csv")
tbot_users_2 = pd.read_csv("C:/Twitter/traditional_spambots_2/users.csv")
tbot_users_3 = pd.read_csv("C:/Twitter/traditional_spambots_3/users.csv")
tbot_users_4 = pd.read_csv("C:/Twitter/traditional_spambots_4/users.csv")

# %%
#Re-attach the separated dataframes

sbot_tweets = pd.concat([sbot_tweets_1, sbot_tweets_2, sbot_tweets_3])
sbot_users = pd.concat([sbot_users_1, sbot_users_2, sbot_users_3])
tbot_users = pd.concat([tbot_users_1, tbot_users_2, tbot_users_3, tbot_users_4])
# Out:
# C:\Users\cct51\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   after removing the cwd from sys.path.

# %%
#Now create a label for where tweets and users came from and attach all datasets together 

sbot_tweets['origin'] = 'socialbot'
genuine_tweets['origin'] = 'real'
ffollow_tweets['origin'] = 'followbot'


sbot_users['origin'] = 'socialbot'
genuine_users['origin'] = 'real'
ffollow_users['origin'] = 'followbot'

# %%
##in order to run well on the laptop, time to trim down the dataset into purely english users. 

ffollow_users_eng = ffollow_users[ffollow_users['lang'] == 'en']
genuine_users_eng = genuine_users[genuine_users['lang'] == 'en']
sbot_users_eng = sbot_users[sbot_users['lang'] == 'en']

# %%
#Sorting in order to check user_id values
genuine_tweets.sort_values(by=['user_id'])
# Out:
#                                                         id  \
# 0                                       593932392663912449
# 2125                                    547384258701312001
# 2126                                    547382436011995136
# 2127                                    547379659630190593
# 2128                                    547377097954832384
# 2129                                    547374989729873920
# 2130                                    547276916831449088
# 2131                                    547267956552388608
# 2132                                    547239980976705536
# 2133                                    547239573420388353
# 2124                                    547447799189864449
# 2134                                    547239328045228032
# 2136                                    547228991006838784
# 2137                                    547224079669805056
# 2138                                    547208566688722945
# 2139                                    547178813244067843
# 2140                                    546911676604624896
# 2141                                    546911421926477824
# 2142                                    546881952566231040
# 2143                                    546881386846896130
# 2144                                    546880618710433793
# 2135                                    547228991997100033
# 2123                                    547448477161357314
# 2122                                    547448918725111808
# 2121                                    547449596130394112
# 2100                                    547919656627884032
# 2101                                    547919188501618688
# 2102                                    547918987875454976
# 2103                                    547918785026326529
# 2104                                    547918666138791937
# ...                                                    ...
# 2835656                                 588736229828665345
# 2837728                                 582828796174299136
# 2837725                                 582828932547915777
# 2837723                                 582833239804502017
# 2835660                                 588734971805851648
# 2837721                                 582833846590263296
# 2837718                                 582837781950525440
# 2837716                                 582844306534330368
# 2835664                                 588734222824775680
# 2837714                                 582845373976281088
# 2837712                                 582848065951932416
# 2837739                                 582820345427685376
# 2837711                                 582848859472310272
# 2837707                                 582849407982432256
# 2835668                                 588731625774649345
# 2837704                                 582849560571219968
# 2835670                                 588731257690923008
# 2837701                                 582849705111101440
# 2837700                                 582849896362995712
# 2835673                                 588730292858388481
# 2837694                                 582850490662260736
# 2835677                                 588729942915047424
# 2837690                                 582889286606958592
# 2835680                                 588728734095646721
# 2835684                                 588728212533944321
# 2837683                                 582895173442674688
# 2837681                                 582896607714271233
# 2837709                                 582849127609950208
# 2835293                                 590496056170913792
# 2839361  Fatal error: Maximum execution time of 300 sec...
#
#                                                       text  \
# 0        RT @morningJewshow: Speaking about Jews and co...
# 2125     RT @chrisgeidner: Thirty-Five Injured In Attac...
# 2126     RT @tanehisicoates: This @HeerJeet ethering is...
# 2127     RT @tanehisicoates: People arguing we should c...
# 2128     @jelani9 Oy. I can't believe you had to spell ...
# 2129     RT @tanehisicoates: People think Goldwater con...
# 2130     Awaiting the moment mums of North America begi...
# 2131     The important thing is that you must have deep...
# 2132     @esmecomfort that would be truly hard for me t...
# 2133     @sandyanne57 thanks! Happy Christmas! @marikot...
# 2124     RT @THErealDVORAK: Please retweet. I continue ...
# 2134     "Power, decoupled from responsibility, is what...
# 2136     360degree sunset power. Joshua Tree. #magicdat...
# 2137     @migurski thanks Michal, It's what a lasting l...
# 2138     I'm sitting right here with you @marikotamaki ...
# 2139     So happy here. RT @marikotamaki  1h1 hour agoB...
# 2140     @jacqui thanks Jaqui. I'm so sorry. Let's have...
# 2141     RT @jacqui: Having gone through it, I can vouc...
# 2142     @arsetechnica NO! The fruit is full of wax. It...
# 2143     RT @ginatrapani: How to unfollow everyone on T...
# 2144     Yes!“@TeamDNTO: “@tsgibson: Serial is done and...
# 2135     Yes I've now reached the age where I wear swea...
# 2123     RT @LindaStone: RT @sciammind: How to Grow Str...
# 2122     @jensmccabe having had my share of hand issues...
# 2121     RT @JustinBrookman: FFS, Marriott is petitioni...
# 2100     Yes I do have an album you can buy. Nosh. It's...
# 2101     @flipcritic what better ass cover than the Pre...
# 2102     @ruthannharnisch I wonder if this Interview "e...
# 2103     It's pretty amazing how much a man's ability t...
# 2104     Podcast discoveries of the trip @pang's Typeca...
# ...                                                    ...
# 2835656  @JuventudCASDF @kikomoroman esa cuenta es "ser...
# 2837728  @subversivos_ @MesaDefensaSani Pero luego pega...
# 2837725  RT @AeropuertoCS: COFRADE!!! TE TOCAN LAS NARI...
# 2837723                        @Pol4hp Viva San Fermín! ¬¬
# 2835660  RT @Acratias: No sé puede olvidar aunque la mi...
# 2837721  RT @quediario: La escalofriante medicina del p...
# 2837718  RT @dinamittEros: Prisión del Castillo de Mont...
# 2837716  @Mapache__ "es que no tiene las flechas y el y...
# 2835664                     @sobranromanxs yo "los" bajos
# 2837714  @Mapache__ Es que es lo "normal" y no puedes q...
# 2837712    @Mapache__ pues que te pique un pollo en el ano
# 2837739  ¿Por qué en esta **** ciudad no hay ningún bue...
# 2837711  Ver las roturas de menisco en RM debería conva...
# 2837707  @SevillaSkinhead sólo te digo que ojalá no se ...
# 2835668  RT @Nephys: Tomb of Amenhotep II, decorated wi...
# 2837704  @SevillaSkinhead ves. Pero cuesta un ratillo h...
# 2835670  @drogopropulsion @sobranromanxs lo sabrás porq...
# 2837701                                 @Mapache__ nucelar
# 2837700  RT @SevillaSkinhead: @BenEWriggle http://t.co/...
# 2835673  @drogopropulsion @sobranromanxs pero yo me ped...
# 2837694  RT @Mapache__: @BenEWriggle con lo bonito que ...
# 2835677  @sobranromanxs Problema. Los antineutrinos se ...
# 2837690  RT @SevillaSkinhead: @BenEWriggle really? http...
# 2835680  @sobranromanxs Yo compro el pegamento que me h...
# 2835684  RT @Cuauhtemoc_1521: El cuauhxicalli o jicara ...
# 2837683  RT @QueDesfase: Peligro de ataque de pene giga...
# 2837681  RT @ShepherdSR: @trailerparkboys Absolutely we...
# 2837709                    @Mapache__ mordida hasta cóccix
# 2835293  Hay momentos en los que me parece que van a sa...
# 2839361                                                NaN
#
#                                                     source       user_id  \
# 0        <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2125     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2126     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2127     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2128     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2129     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2130     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2131     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2132     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2133     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2124     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2134     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2136     <a href="http://instagram.com" rel="nofollow">...  6.780330e+05
# 2137     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2138     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2139     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2140     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2141     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2142     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2143     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2144     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2135     <a href="http://instagram.com" rel="nofollow">...  6.780330e+05
# 2123     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2122     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2121     <a href="http://tapbots.com/tweetbot" rel="nof...  6.780330e+05
# 2100     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2101     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2102     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2103     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# 2104     <a href="http://twitter.com" rel="nofollow">Tw...  6.780330e+05
# ...                                                    ...           ...
# 2835656  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837728  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837725  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837723  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835660  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837721  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837718  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837716  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835664  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837714  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837712  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837739  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837711  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837707  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835668  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837704  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835670  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837701  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837700  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835673  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837694  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835677  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837690  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835680  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835684  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837683  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837681  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2837709  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2835293  <a href="http://twitter.com" rel="nofollow">Tw...  2.356426e+09
# 2839361                                                NaN           NaN
#
#          truncated  in_reply_to_status_id  in_reply_to_user_id  \
# 0              NaN           0.000000e+00         0.000000e+00
# 2125           NaN           0.000000e+00         0.000000e+00
# 2126           NaN           0.000000e+00         0.000000e+00
# 2127           NaN           0.000000e+00         0.000000e+00
# 2128           NaN           5.471531e+17         1.415591e+07
# 2129           NaN           0.000000e+00         0.000000e+00
# 2130           NaN           0.000000e+00         0.000000e+00
# 2131           NaN           0.000000e+00         0.000000e+00
# 2132           NaN           5.472327e+17         1.202174e+08
# 2133           NaN           5.472312e+17         8.259076e+08
# 2124           NaN           0.000000e+00         0.000000e+00
# 2134           NaN           0.000000e+00         0.000000e+00
# 2136           NaN           0.000000e+00         0.000000e+00
# 2137           NaN           5.472106e+17         2.790981e+06
# 2138           NaN           0.000000e+00         0.000000e+00
# 2139           NaN           0.000000e+00         0.000000e+00
# 2140           NaN           5.467288e+17         3.552030e+05
# 2141           NaN           0.000000e+00         0.000000e+00
# 2142           NaN           5.468811e+17         2.884045e+07
# 2143           NaN           0.000000e+00         0.000000e+00
# 2144           NaN           0.000000e+00         0.000000e+00
# 2135           NaN           0.000000e+00         0.000000e+00
# 2123           NaN           0.000000e+00         0.000000e+00
# 2122           NaN           5.474436e+17         1.425804e+07
# 2121           NaN           0.000000e+00         0.000000e+00
# 2100           NaN           0.000000e+00         0.000000e+00
# 2101           NaN           5.479190e+17         9.381618e+07
# 2102           NaN           5.479187e+17         1.835140e+07
# 2103           NaN           0.000000e+00         0.000000e+00
# 2104           NaN           0.000000e+00         0.000000e+00
# ...            ...                    ...                  ...
# 2835656        NaN           5.867892e+17         3.527253e+08
# 2837728        NaN           5.828150e+17         2.823392e+08
# 2837725        NaN           0.000000e+00         0.000000e+00
# 2837723        NaN           5.828301e+17         2.502784e+09
# 2835660        NaN           0.000000e+00         0.000000e+00
# 2837721        NaN           0.000000e+00         0.000000e+00
# 2837718        NaN           0.000000e+00         0.000000e+00
# 2837716        NaN           5.828398e+17         8.930611e+08
# 2835664        NaN           5.887340e+17         7.787089e+08
# 2837714        NaN           5.828446e+17         8.930611e+08
# 2837712        NaN           5.828470e+17         8.930611e+08
# 2837739        NaN           0.000000e+00         0.000000e+00
# 2837711        NaN           0.000000e+00         0.000000e+00
# 2837707        NaN           5.828490e+17         1.883456e+09
# 2835668        NaN           0.000000e+00         0.000000e+00
# 2837704        NaN           5.828494e+17         2.356426e+09
# 2835670        NaN           5.887308e+17         2.960707e+09
# 2837701        NaN           5.828496e+17         8.930611e+08
# 2837700        NaN           0.000000e+00         0.000000e+00
# 2835673        NaN           5.887300e+17         2.960707e+09
# 2837694        NaN           0.000000e+00         0.000000e+00
# 2835677        NaN           5.887289e+17         7.787089e+08
# 2837690        NaN           0.000000e+00         0.000000e+00
# 2835680        NaN           5.887253e+17         7.787089e+08
# 2835684        NaN           0.000000e+00         0.000000e+00
# 2837683        NaN           0.000000e+00         0.000000e+00
# 2837681        NaN           0.000000e+00         0.000000e+00
# 2837709        NaN           5.828486e+17         8.930611e+08
# 2835293        NaN           0.000000e+00         0.000000e+00
# 2839361        NaN                    NaN                  NaN
#
#         in_reply_to_screen_name  retweeted_status_id  geo   ...   retweeted  \
# 0                           NaN         5.939322e+17  NaN   ...         NaN
# 2125                        NaN         5.471446e+17  NaN   ...         NaN
# 2126                        NaN         5.472183e+17  NaN   ...         NaN
# 2127                        NaN         5.471561e+17  NaN   ...         NaN
# 2128                    jelani9         0.000000e+00  NaN   ...         NaN
# 2129                        NaN         5.472230e+17  NaN   ...         NaN
# 2130                        NaN         0.000000e+00  NaN   ...         NaN
# 2131                        NaN         0.000000e+00  NaN   ...         NaN
# 2132                esmecomfort         0.000000e+00  NaN   ...         NaN
# 2133                sandyanne57         0.000000e+00  NaN   ...         NaN
# 2124                        NaN         5.474383e+17  NaN   ...         NaN
# 2134                        NaN         0.000000e+00  NaN   ...         NaN
# 2136                        NaN         0.000000e+00  NaN   ...         NaN
# 2137                   migurski         0.000000e+00  NaN   ...         NaN
# 2138                        NaN         0.000000e+00  NaN   ...         NaN
# 2139                        NaN         0.000000e+00  NaN   ...         NaN
# 2140                     jacqui         0.000000e+00  NaN   ...         NaN
# 2141                        NaN         5.467288e+17  NaN   ...         NaN
# 2142               arsetechnica         0.000000e+00  NaN   ...         NaN
# 2143                        NaN         5.467955e+17  NaN   ...         NaN
# 2144                        NaN         0.000000e+00  NaN   ...         NaN
# 2135                        NaN         0.000000e+00  NaN   ...         NaN
# 2123                        NaN         5.474417e+17  NaN   ...         NaN
# 2122                 jensmccabe         0.000000e+00  NaN   ...         NaN
# 2121                        NaN         5.474248e+17  NaN   ...         NaN
# 2100                        NaN         0.000000e+00  NaN   ...         NaN
# 2101                 flipcritic         0.000000e+00  NaN   ...         NaN
# 2102            ruthannharnisch         0.000000e+00  NaN   ...         NaN
# 2103                        NaN         0.000000e+00  NaN   ...         NaN
# 2104                        NaN         0.000000e+00  NaN   ...         NaN
# ...                         ...                  ...  ...   ...         ...
# 2835656           JuventudCASDF         0.000000e+00  NaN   ...         NaN
# 2837728            subversivos_         0.000000e+00  NaN   ...         NaN
# 2837725                     NaN         5.826035e+17  NaN   ...         NaN
# 2837723                  Pol4hp         0.000000e+00  NaN   ...         NaN
# 2835660                     NaN         5.887345e+17  NaN   ...         NaN
# 2837721                     NaN         5.828284e+17  NaN   ...         NaN
# 2837718                     NaN         5.828354e+17  NaN   ...         NaN
# 2837716               Mapache__         0.000000e+00  NaN   ...         NaN
# 2835664           sobranromanxs         0.000000e+00  NaN   ...         NaN
# 2837714               Mapache__         0.000000e+00  NaN   ...         NaN
# 2837712               Mapache__         0.000000e+00  NaN   ...         NaN
# 2837739                     NaN         0.000000e+00  NaN   ...         NaN
# 2837711                     NaN         0.000000e+00  NaN   ...         NaN
# 2837707         SevillaSkinhead         0.000000e+00  NaN   ...         NaN
# 2835668                     NaN         5.887316e+17  NaN   ...         NaN
# 2837704             BenEWriggle         0.000000e+00  NaN   ...         NaN
# 2835670         drogopropulsion         0.000000e+00  NaN   ...         NaN
# 2837701               Mapache__         0.000000e+00  NaN   ...         NaN
# 2837700                     NaN         5.828498e+17  NaN   ...         NaN
# 2835673         drogopropulsion         0.000000e+00  NaN   ...         NaN
# 2837694                     NaN         5.828504e+17  NaN   ...         NaN
# 2835677           sobranromanxs         0.000000e+00  NaN   ...         NaN
# 2837690                     NaN         5.828886e+17  NaN   ...         NaN
# 2835680           sobranromanxs         0.000000e+00  NaN   ...         NaN
# 2835684                     NaN         5.887256e+17  NaN   ...         NaN
# 2837683                     NaN         5.828942e+17  NaN   ...         NaN
# 2837681                     NaN         5.828522e+17  NaN   ...         NaN
# 2837709               Mapache__         0.000000e+00  NaN   ...         NaN
# 2835293                     NaN         0.000000e+00  NaN   ...         NaN
# 2839361                     NaN                  NaN  NaN   ...         NaN
#
#          possibly_sensitive  num_hashtags  num_urls  num_mentions  \
# 0                       NaN           0.0       0.0           1.0
# 2125                    NaN           0.0       1.0           2.0
# 2126                    NaN           0.0       1.0           2.0
# 2127                    NaN           0.0       0.0           1.0
# 2128                    NaN           0.0       0.0           3.0
# 2129                    NaN           0.0       0.0           1.0
# 2130                    NaN           1.0       0.0           0.0
# 2131                    NaN           1.0       0.0           0.0
# 2132                    NaN           0.0       0.0           1.0
# 2133                    NaN           0.0       0.0           2.0
# 2124                    NaN           0.0       1.0           1.0
# 2134                    NaN           1.0       1.0           1.0
# 2136                    NaN           2.0       1.0           0.0
# 2137                    NaN           0.0       0.0           1.0
# 2138                    NaN           2.0       0.0           1.0
# 2139                    NaN           1.0       1.0           2.0
# 2140                    NaN           0.0       0.0           1.0
# 2141                    NaN           0.0       1.0           1.0
# 2142                    NaN           0.0       0.0           1.0
# 2143                    NaN           0.0       1.0           1.0
# 2144                    NaN           0.0       1.0           2.0
# 2135                    NaN           0.0       1.0           0.0
# 2123                    NaN           0.0       1.0           2.0
# 2122                    NaN           0.0       0.0           1.0
# 2121                    NaN           0.0       1.0           1.0
# 2100                    NaN           2.0       0.0           0.0
# 2101                    NaN           0.0       0.0           1.0
# 2102                    NaN           0.0       0.0           3.0
# 2103                    NaN           1.0       0.0           0.0
# 2104                    NaN           1.0       0.0           2.0
# ...                     ...           ...       ...           ...
# 2835656                 NaN           0.0       0.0           2.0
# 2837728                 NaN           0.0       0.0           2.0
# 2837725                 NaN           0.0       0.0           1.0
# 2837723                 NaN           0.0       0.0           1.0
# 2835660                 NaN           0.0       0.0           1.0
# 2837721                 NaN           0.0       1.0           1.0
# 2837718                 NaN           0.0       0.0           1.0
# 2837716                 NaN           0.0       0.0           1.0
# 2835664                 NaN           0.0       0.0           1.0
# 2837714                 NaN           0.0       0.0           1.0
# 2837712                 NaN           0.0       0.0           1.0
# 2837739                 NaN           0.0       0.0           0.0
# 2837711                 NaN           1.0       0.0           0.0
# 2837707                 NaN           0.0       0.0           1.0
# 2835668                 NaN           0.0       0.0           1.0
# 2837704                 NaN           1.0       0.0           1.0
# 2835670                 NaN           0.0       0.0           2.0
# 2837701                 NaN           0.0       0.0           1.0
# 2837700                 NaN           0.0       0.0           2.0
# 2835673                 NaN           0.0       0.0           2.0
# 2837694                 NaN           0.0       0.0           2.0
# 2835677                 NaN           0.0       0.0           1.0
# 2837690                 NaN           0.0       0.0           2.0
# 2835680                 NaN           0.0       0.0           1.0
# 2835684                 NaN           0.0       0.0           1.0
# 2837683                 NaN           0.0       0.0           1.0
# 2837681                 NaN           0.0       0.0           2.0
# 2837709                 NaN           0.0       0.0           1.0
# 2835293                 NaN           0.0       1.0           0.0
# 2839361                 NaN           NaN       NaN           NaN
#
#                              created_at            timestamp  \
# 0        Fri May 01 00:18:11 +0000 2015  2015-05-01 02:18:11
# 2125     Tue Dec 23 13:32:31 +0000 2014  2014-12-23 14:32:31
# 2126     Tue Dec 23 13:25:17 +0000 2014  2014-12-23 14:25:17
# 2127     Tue Dec 23 13:14:15 +0000 2014  2014-12-23 14:14:15
# 2128     Tue Dec 23 13:04:04 +0000 2014  2014-12-23 14:04:04
# 2129     Tue Dec 23 12:55:41 +0000 2014  2014-12-23 13:55:41
# 2130     Tue Dec 23 06:25:59 +0000 2014  2014-12-23 07:25:59
# 2131     Tue Dec 23 05:50:23 +0000 2014  2014-12-23 06:50:23
# 2132     Tue Dec 23 03:59:13 +0000 2014  2014-12-23 04:59:13
# 2133     Tue Dec 23 03:57:36 +0000 2014  2014-12-23 04:57:36
# 2124     Tue Dec 23 17:45:01 +0000 2014  2014-12-23 18:45:01
# 2134     Tue Dec 23 03:56:37 +0000 2014  2014-12-23 04:56:37
# 2136     Tue Dec 23 03:15:33 +0000 2014  2014-12-23 04:15:33
# 2137     Tue Dec 23 02:56:02 +0000 2014  2014-12-23 03:56:02
# 2138     Tue Dec 23 01:54:23 +0000 2014  2014-12-23 02:54:23
# 2139     Mon Dec 22 23:56:09 +0000 2014  2014-12-23 00:56:09
# 2140     Mon Dec 22 06:14:39 +0000 2014  2014-12-22 07:14:39
# 2141     Mon Dec 22 06:13:38 +0000 2014  2014-12-22 07:13:38
# 2142     Mon Dec 22 04:16:32 +0000 2014  2014-12-22 05:16:32
# 2143     Mon Dec 22 04:14:17 +0000 2014  2014-12-22 05:14:17
# 2144     Mon Dec 22 04:11:14 +0000 2014  2014-12-22 05:11:14
# 2135     Tue Dec 23 03:15:33 +0000 2014  2014-12-23 04:15:33
# 2123     Tue Dec 23 17:47:42 +0000 2014  2014-12-23 18:47:42
# 2122     Tue Dec 23 17:49:27 +0000 2014  2014-12-23 18:49:27
# 2121     Tue Dec 23 17:52:09 +0000 2014  2014-12-23 18:52:09
# 2100     Thu Dec 25 01:00:00 +0000 2014  2014-12-25 02:00:00
# 2101     Thu Dec 25 00:58:09 +0000 2014  2014-12-25 01:58:09
# 2102     Thu Dec 25 00:57:21 +0000 2014  2014-12-25 01:57:21
# 2103     Thu Dec 25 00:56:32 +0000 2014  2014-12-25 01:56:32
# 2104     Thu Dec 25 00:56:04 +0000 2014  2014-12-25 01:56:04
# ...                                 ...                  ...
# 2835656  Thu Apr 16 16:10:30 +0000 2015  2015-04-16 18:10:30
# 2837728  Tue Mar 31 08:56:28 +0000 2015  2015-03-31 10:56:28
# 2837725  Tue Mar 31 08:57:00 +0000 2015  2015-03-31 10:57:00
# 2837723  Tue Mar 31 09:14:07 +0000 2015  2015-03-31 11:14:07
# 2835660  Thu Apr 16 16:05:30 +0000 2015  2015-04-16 18:05:30
# 2837721  Tue Mar 31 09:16:32 +0000 2015  2015-03-31 11:16:32
# 2837718  Tue Mar 31 09:32:10 +0000 2015  2015-03-31 11:32:10
# 2837716  Tue Mar 31 09:58:06 +0000 2015  2015-03-31 11:58:06
# 2835664  Thu Apr 16 16:02:31 +0000 2015  2015-04-16 18:02:31
# 2837714  Tue Mar 31 10:02:20 +0000 2015  2015-03-31 12:02:20
# 2837712  Tue Mar 31 10:13:02 +0000 2015  2015-03-31 12:13:02
# 2837739  Tue Mar 31 08:22:53 +0000 2015  2015-03-31 10:22:53
# 2837711  Tue Mar 31 10:16:11 +0000 2015  2015-03-31 12:16:11
# 2837707  Tue Mar 31 10:18:22 +0000 2015  2015-03-31 12:18:22
# 2835668  Thu Apr 16 15:52:12 +0000 2015  2015-04-16 17:52:12
# 2837704  Tue Mar 31 10:18:58 +0000 2015  2015-03-31 12:18:58
# 2835670  Thu Apr 16 15:50:44 +0000 2015  2015-04-16 17:50:44
# 2837701  Tue Mar 31 10:19:33 +0000 2015  2015-03-31 12:19:33
# 2837700  Tue Mar 31 10:20:18 +0000 2015  2015-03-31 12:20:18
# 2835673  Thu Apr 16 15:46:54 +0000 2015  2015-04-16 17:46:54
# 2837694  Tue Mar 31 10:22:40 +0000 2015  2015-03-31 12:22:40
# 2835677  Thu Apr 16 15:45:31 +0000 2015  2015-04-16 17:45:31
# 2837690  Tue Mar 31 12:56:50 +0000 2015  2015-03-31 14:56:50
# 2835680  Thu Apr 16 15:40:42 +0000 2015  2015-04-16 17:40:42
# 2835684  Thu Apr 16 15:38:38 +0000 2015  2015-04-16 17:38:38
# 2837683  Tue Mar 31 13:20:13 +0000 2015  2015-03-31 15:20:13
# 2837681  Tue Mar 31 13:25:55 +0000 2015  2015-03-31 15:25:55
# 2837709  Tue Mar 31 10:17:15 +0000 2015  2015-03-31 12:17:15
# 2835293  Tue Apr 21 12:43:25 +0000 2015  2015-04-21 14:43:25
# 2839361                             NaN                  NaN
#
#                   crawled_at              updated  origin
# 0        2015-05-01 12:57:19  2015-05-01 12:57:19    real
# 2125     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2126     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2127     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2128     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2129     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2130     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2131     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2132     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2133     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2124     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2134     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2136     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2137     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2138     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2139     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2140     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2141     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2142     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2143     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2144     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2135     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2123     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2122     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2121     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2100     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2101     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2102     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2103     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# 2104     2015-05-01 12:57:22  2015-05-01 12:57:22    real
# ...                      ...                  ...     ...
# 2835656  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2837728  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837725  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837723  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2835660  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2837721  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837718  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837716  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2835664  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2837714  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837712  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837739  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837711  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837707  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2835668  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2837704  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2835670  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2837701  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837700  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2835673  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2837694  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2835677  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2837690  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2835680  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2835684  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2837683  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837681  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2837709  2015-05-01 16:15:16  2015-05-01 16:15:16    real
# 2835293  2015-05-01 16:15:14  2015-05-01 16:15:14    real
# 2839361                  NaN                  NaN    real
#
# [2839362 rows x 26 columns]

# %%
#Abbreviate columns to just relevant ones 
sbot_abbr = sbot_tweets[['id', 'user_id', 'text', 'num_hashtags', 'num_urls', 'num_mentions', 'timestamp', 'origin']]
genuine_abbr = genuine_tweets[['id', 'user_id', 'text', 'num_hashtags', 'num_urls', 'num_mentions', 'timestamp', 'origin']]
ffollow_abbr = ffollow_tweets[['id', 'user_id', 'text', 'num_hashtags', 'num_urls', 'num_mentions', 'timestamp', 'origin']]

# %%
#Eliminate any rows with empty values 
sbot_abbr_clean = sbot_abbr.dropna()
genuine_abbr_clean = genuine_abbr.dropna()
ffollow_abbr_clean = ffollow_abbr.dropna()

# %%
#Turn all id's into integers.
genuine_abbr_clean['user_id'] = genuine_abbr_clean['user_id'].astype('int64')
sbot_abbr_clean['user_id'] = sbot_abbr_clean['user_id'].astype('int64')
ffollow_abbr_clean['user_id'] = ffollow_abbr_clean['user_id'].astype('int64')
# Out:
# C:\Users\cct51\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\cct51\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\cct51\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
genuine_id_list = list(genuine_users_eng['id'][:500])
sbot_id_list = list(sbot_users_eng['id'][:500])

# %%
idx = 0 

genuine_tweets_set = []

while idx < 280000:
    if genuine_abbr_clean.iloc[idx, 1] in genuine_id_list :
        genuine_tweets_set.append(genuine_tweets.iloc[idx, :])
    idx += 1 
    
genuine_tweets_df = pd.DataFrame(genuine_tweets_set)

# %%
#Length of 46,191 sbot tweets

idx = 0 

sbot_tweets_set = []

while idx < 280000:
    if sbot_abbr_clean.iloc[idx, 1] in sbot_id_list :
        sbot_tweets_set.append(sbot_tweets.iloc[idx, :])
    idx += 1 
    
sbot_tweets_df = pd.DataFrame(sbot_tweets_set)

# %%
# Merge, then trim down the datasets here
genuine_combined_eng = pd.merge(genuine_users_eng, genuine_tweets_df, how='inner', left_on = 'id', right_on = 'user_id')
sbot_combined_eng = pd.merge(sbot_users_eng, sbot_tweets_df, how='inner', left_on = 'id', right_on = 'user_id')

# %%
#Complete prepping the rest of the data

genuine_combined_eng = genuine_combined_eng[['id_x', 'name', 'screen_name', 'statuses_count', 'followers_count', 'friends_count', 'favourites_count', 'listed_count', 'created_at_y', 'text', 'num_hashtags', 'num_urls', 'num_mentions', 'origin_x']]
genuine_combined = genuine_combined_eng.dropna()
sbot_combined_eng = sbot_combined_eng[['id_x', 'name', 'screen_name', 'statuses_count', 'followers_count', 'friends_count', 'favourites_count', 'listed_count', 'created_at_y', 'text', 'num_hashtags', 'num_urls', 'num_mentions', 'origin_x']]
sbot_combined = sbot_combined_eng.dropna()

ffollow_combined_eng = pd.merge(ffollow_users_eng, ffollow_tweets, how='inner', left_on = 'id', right_on='user_id')
ffollow_combined= ffollow_combined_eng[['id_x', 'name', 'screen_name', 'statuses_count', 'followers_count', 'friends_count', 'favourites_count', 'listed_count', 'created_at_y', 'text', 'num_hashtags', 'num_urls', 'num_mentions', 'origin_x']]

# %%
#Shuffle the dataframe before slicing
ffollow_combined = ffollow_combined.sample(frac=1)
genuine_combined = genuine_combined.sample(frac=1)
sbot_combined = sbot_combined.sample(frac=1)


#dataframe.sample frac = 1 (find a better way to shuffle the dataframe -> Returns a shuffled frame)

# %%
#Trim the size of these dang datatsets 
#Also assemble our test, validation, and test sets
ffollow_combined_eng_cut = ffollow_combined[:24000]
validation_cut_1 = ffollow_combined[24000:32000]
test_cut_1 = ffollow_combined[32000:40000]
genuine_combined_eng_cut = genuine_combined[:24000]
validation_cut_2 = genuine_combined[24000:32000]
test_cut_2 = genuine_combined[32000:40000]
sbot_combined_eng_cut = sbot_combined[:24000]
validation_cut_3 = sbot_combined[24000:32000]
test_cut_3 = sbot_combined[32000:40000]

# %%
#Combine the datasets together 
all_tweets = pd.concat([sbot_combined_eng_cut, ffollow_combined_eng_cut, genuine_combined_eng_cut])
validation_cut = pd.concat([validation_cut_1, validation_cut_2, validation_cut_3])
test_cut = pd.concat([test_cut_1, test_cut_2, test_cut_3])

# %%
train = all_tweets['friends_count']
test = test_cut['friends_count']
bins = np.linspace(0, 5000, 100)

plt.hist(train, bins, alpha=0.5, label='Training text', color='red')
plt.hist(test, bins, alpha=0.5, label='Test text', color='black')
plt.xlabel('')
plt.legend(loc='upper right')
plt.title('Friends count distribution in training and test data', fontsize=14)
plt.show()

"""
The feature distribution of the training sample and the test sample, at least in terms of friends, seems similar enough between the
two conditions. This suggests a good level of external validity in test results. 
"""

# %%
#Bring in Natural Language Processing Tools
import nltk 

from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(min_df=0)
#Look at nltk resources then begin!

# %%
#Define make_xy generic function


def make_xy(tweets, vectorizer=None):
        
    if vectorizer is None:
        vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(tweets.text)
    X = X.tocsc()  # some versions of sklearn return COO format
    y = (tweets['origin_x'] == 'real').values.astype(np.int)
    return X, y

#X, y = make_xy(all_tweets)

# %%
all_tweets = all_tweets.dropna()

# %%
vectorizer.fit(all_tweets['text'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=0,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
x = vectorizer.transform(all_tweets['text'])

# %%
def top_tfidf_featstop_tfid (row, features, top_n=10):
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats)
    df.columns = ['feature', 'tfidf']
    return df

def top_feats_in_doc(Xtr, features, row_id, top_n=10):
    row = np.squeeze(Xtr[row_id].toarray())
    return top_tfidf_feats(row, features, top_n)

def top_mean_feats(Xtr, features, grp_ids=None, min_tfidf=0.1, top_n=10):
    if grp_ids:
        D = Xtr[grp_ids].toarray()
    else:
        D = Xtr.toarray()

    D[D < min_tfidf] = 0
    tfidf_means = np.mean(D, axis=0)
    return top_tfidf_feats(tfidf_means, features, top_n)

def top_feats_by_class(Xtr, y, features, min_tfidf=0.1, top_n=10):
    dfs = []
    #labels = np.unique(y)
    labels = [2,7]
    for label in labels:
        ids = np.where(y==label)
        feats_df = top_mean_feats(Xtr, features, ids, min_tfidf=min_tfidf, top_n=top_n)
        feats_df.label = label
        dfs.append(feats_df)
    return dfs

def plot_tfidf_classfeats_h(dfs):
    fig = plt.figure(figsize=(8, 30), facecolor="w")
    x = np.arange(len(dfs[0]))
    for i, df in enumerate(dfs):
        #z = int(str(int(i/3)+1) + str((i%3)+1))
        ax = fig.add_subplot(9, 1, i+1)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.set_frame_on(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()
        ax.set_xlabel("Mean Tf-Idf Score", labelpad=16, fontsize=16)
        ax.set_ylabel("Word", labelpad=16, fontsize=16)
        ax.set_title("Class = " + str(df.label), fontsize=18)
        ax.ticklabel_format(axis='x', style='sci', scilimits=(-2,2))
        ax.barh(x, df.tfidf, align='center')
        ax.set_yticks(x)
        ax.set_ylim([-1, x[-1]+1])
        yticks = ax.set_yticklabels(df.feature)
        plt.subplots_adjust(bottom=0.09, right=0.97, left=0.15, top=0.95, wspace=0.52)
    plt.show()

# %%
#Need tfidf transform first
from sklearn.feature_extraction.text import TfidfVectorizer
def top_tfidf_feats(row, features, top_n=10):
    topn_ids = np.argsort(row)[::-1][:top_n] #<--- argsort? 
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats)
    df.columns = ['feature', 'tfidf'] #<--- Makes dataframe of top 10 most common features 
    return df

tfidf = TfidfVectorizer(min_df=6, max_df=0.75).fit(all_tweets["text"])

# %%
def top_feats_in_doc(Xtr, features, row_id, top_n=25):
    row = np.squeeze(Xtr[row_id].toarray())
    return top_tfidf_feats(row, features, top_n)

# %% [markdown]
# Exploratory Data Analysis

# %%
from itertools import chain

categ_vars = ['origin_x', 'num_mentions', 'num_hashtags', 'num_urls']
fig, ax = plt.subplots(nrows = 2, ncols = 2 ,figsize=(20,10))
fig.subplots_adjust(wspace=0.4, hspace=0.4)
ax = list(chain.from_iterable(ax)) #Change ax from matrix to a list for iteration 
for i in range(len(categ_vars)):
    sns.countplot(all_tweets[categ_vars[i]], hue=all_tweets['origin_x'], ax=ax[i])
    plt.ylabel("percent")
    plt.plot()
    
    
#ax = sns.barplot(x="x", y="x", data=df, estimator=lambda x: len(x) / len(df) * 100)
#ax.set(ylabel="Percent")

# %%
sns.barplot(x='num_mentions', y='num_mentions', data=all_tweets, estimator=lambda x: len(x)/len(all_tweets) * 100,hue=all_tweets['origin_x'])
plt.ylabel("Percent of Dataset")
plt.xlabel("Number of mentions")
plt.title("Frequency Distribution of Tweets WRT Mentions")
plt.xlim(xmax=5)

#It appears that the more mentions that are included in a tweet, the more likely it is to be real. 
#Also of note is that follow bots tend to use the "mention" feature more than typical social bots.
# Out:
# (-0.5, 5)

# %%
sns.barplot(x='num_urls', y='num_urls', data=all_tweets, estimator=lambda x: len(x)/len(all_tweets) * 100,hue=all_tweets['origin_x'])
plt.ylabel("Percent of Dataset")
plt.xlabel("Number of Links")
plt.title("Socialbot Tweets Don't Include Links")
plt.xlim(xmax=3)
# Out:
# (-0.5, 3)

# %%
sns.barplot(x='num_hashtags', y='num_hashtags', data=all_tweets, estimator=lambda x: len(x)/len(all_tweets) * 100,hue=all_tweets['origin_x'])
plt.ylabel("Percent of Dataset")
plt.xlabel("Number of Hashtags")
plt.title("Everyone uses Hashtags")
plt.xlim(xmax=4)
# Out:
# (-0.5, 4)

# %%
#Make categories out of followers

idx = 0 
all_tweets['followers_bucket'] = 0

while idx < len(all_tweets) :

    if all_tweets.iloc[idx, 4] == 0 :
        all_tweets.iloc[idx, 14] = "0 followers"
    elif all_tweets.iloc[idx, 4] <= 5: 
        all_tweets.iloc[idx, 14] = "0-5 followers"
    elif all_tweets.iloc[idx, 4] <= 25:
        all_tweets.iloc[idx, 14] = "6-25 followers"
    elif all_tweets.iloc[idx, 4] <= 100:
        all_tweets.iloc[idx, 14] = "26-100 followers"
    elif all_tweets.iloc[idx, 4] <= 500: 
        all_tweets.iloc[idx, 14] = "101-500 followers"
    else :
        all_tweets.iloc[idx, 14] = "500+ followers"
    idx += 1

all_tweets.head()
# Out:
#             id_x              name    screen_name  statuses_count  \
# 32622  434729769  Isacco Tombolini    IsaccoTombo             458
# 7978   237192993      Monica Carta    Moniqueeo84             513
# 24736  237375183     Lydia Wallace      Lydiali76             497
# 44798  465401166      Volk Silvers    ViolaTorino             275
# 39933  434775697     Adolfo Pecoro  HadenDamonuyo             467
#
#        followers_count  friends_count  favourites_count  listed_count  \
# 32622             4447           4807                 0             1
# 7978              5772           6022                 0             7
# 24736             4420           4731                 0             5
# 44798             3831           4216                 0             1
# 39933             4116           4527                 0             6
#
#                          created_at_y  \
# 32622  Wed Jul 16 05:09:41 +0000 2014
# 7978   Thu Apr 24 07:28:57 +0000 2014
# 24736  Sun Apr 20 18:09:42 +0000 2014
# 44798  Thu Oct 30 23:07:51 +0000 2014
# 39933  Sat Feb 15 06:49:39 +0000 2014
#
#                                                     text  num_hashtags  \
# 32622  Era bello far l'amore in silenzio, nei portoni...           0.0
# 7978   -Tutti noi abbiamo bisogno di credere in qualc...           0.0
# 24736  il Web compie 25 anni, festeggierà spegnendo d...           0.0
# 44798  Mai disperarsi per chi va via dalla tua vita.....           0.0
# 39933  I ragazzini di oggi, senza ginocchia sbucciate...           0.0
#
#        num_urls  num_mentions   origin_x followers_bucket
# 32622       0.0           0.0  socialbot   500+ followers
# 7978        0.0           0.0  socialbot   500+ followers
# 24736       0.0           0.0  socialbot   500+ followers
# 44798       0.0           0.0  socialbot   500+ followers
# 39933       0.0           0.0  socialbot   500+ followers

# %%
followers_order = ["0 followers", "0-5 followers", "6-25 followers", "26-100 followers", "101-500 followers", "500+ followers"]
sorted_tweets = all_tweets.set_index("followers_bucket").loc[followers_order]

# %%
graph = sns.countplot(x=sorted_tweets.index, data=sorted_tweets, hue=sorted_tweets['origin_x'], order=sorted_tweets.index.value_counts().index)
plt.xticks(rotation=85)
plt.title('Real Accounts (Almost) Never Have Fewer than 100 followers')

#By sorting in descending count order, it becomes apparent that (1) bots built to follow have very few followers themselves,
#(2) social bots tend to compensate with an extremely large number of followers, and (3) real accounts nearly always have alt least over 100 followers
# Out:
# Text(0.5,1,'Real Accounts (Almost) Never Have Fewer than 100 followers')

# %% [markdown]
# -----------------------------Word and model processing----------------------------------------

# %%
#In order to tune hyperparameters of our count vectorizer, let's look
#for an elbow value that captures a sizeable portion of our dataframe
#without overfitting.

#set up grid
sns.set_style("whitegrid")
sns.set_context("poster")

# plot to find minimum df
vectorizer = CountVectorizer(min_df=1)
X,y = make_xy(all_tweets,vectorizer=vectorizer)
dfs = []
for i in range(1,50):
    vectorizer = CountVectorizer(max_df=i)
    X,y = make_xy(all_tweets,vectorizer=vectorizer)
    dfs.append(X.shape[1])
dfs_percent = [df/31690362 for df in dfs]
plt.plot(range(1,50),dfs_percent)
plt.xlabel('Number of df', fontsize=14)
plt.ylabel('Percent of df', fontsize=14)

#The graph shows an elbow in the graph around a min_df of about
#6 or 7. This will define the CountVectorizer as we move forward
# Out:
# Text(0,0.5,'Percent of df')

# %%
#Simplifying columns, reducing origin to a single word.
all_tweets2 = all_tweets.rename(index=str, columns={"id_x": "id", "name": "name", "screen_name": "screen_name", "statuses_count":"statuses_count", "followers_count":"followers_count", "friends_count":"friends_count", "favourites_count":"favorites_count", "listed_count": "listed_count", "created_at_y":"created_at", "text": "text", "num_hashtags":"num_hashtags", "num_urls":"num_urls", "num_mentions":"num_mentions", "origin_x":"origin"})
validation_cut2 = validation_cut.rename(index=str, columns={"id_x": "id", "name": "name", "screen_name": "screen_name", "statuses_count":"statuses_count", "followers_count":"followers_count", "friends_count":"friends_count", "favourites_count":"favorites_count", "listed_count": "listed_count", "created_at_y":"created_at", "text": "text", "num_hashtags":"num_hashtags", "num_urls":"num_urls", "num_mentions":"num_mentions", "origin_x":"origin"})
test_cut2 = test_cut.rename(index=str, columns={"id_x": "id", "name": "name", "screen_name": "screen_name", "statuses_count":"statuses_count", "followers_count":"followers_count", "friends_count":"friends_count", "favourites_count":"favorites_count", "listed_count": "listed_count", "created_at_y":"created_at", "text": "text", "num_hashtags":"num_hashtags", "num_urls":"num_urls", "num_mentions":"num_mentions", "origin_x":"origin"})

# %%
from sklearn.model_selection import train_test_split

y = all_tweets2['origin']
X_train, X_test, y_train, y_test = train_test_split(all_tweets2['text'], y, test_size=0.33, random_state=53)

# %%
def word_vect(vectorizer):
    train = vectorizer.fit_transform(X_train.values)
    test = vectorizer.transform(X_test.values)
    return vectorizer,train,test

from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer,count_train,count_test = word_vect(vectorizer = CountVectorizer(min_df=6, stop_words='english'))
print('features length of counter vectorizer: ', len(count_vectorizer.get_feature_names()))
# Out:
# features length of counter vectorizer:  9716

# %% [markdown]
# Machine Learning Model Section

# %%
# Model #1: Unmodified model 

from sklearn.model_selection import train_test_split
import sklearn.naive_bayes

#1. Initialize a vectorizer with min_df of 0
vectorizer = CountVectorizer(min_df=7)

#2. Create a new Multinomial classifier model with trial alpha
model = sklearn.naive_bayes.MultinomialNB(alpha=1)

#3. Fit the vectorizer to get all of the quotes into the appropriate format
vectorizer.fit_transform(all_tweets.text)

#4. Make X, y for training sets 
X, y = make_xy(all_tweets, vectorizer)

# %%
#5. Fit the model to the transformed quotes
model.fit(X, y)

test_cut = test_cut.dropna()
testX = vectorizer.transform(test_cut.text)
testX = testX.tocsc()
testy = (test_cut['origin_x'] == 'real').values.astype(np.int)

model.score(testX, testy)

#Our unmodified model is about 80% accurate at predicting whether a tweet is real or fake, and what kind of a fake it might be.
# Out:
# 0.7822318526543879

# %%
# Model #2: tfidf model 

from sklearn.model_selection import train_test_split
import sklearn.naive_bayes

#1. Initialize a vectorizer with min_df of 0
vectorizer = TfidfVectorizer(stop_words='english', min_df=7)

#2. Create a new Multinomial classifier model with trial alpha
model = sklearn.naive_bayes.MultinomialNB(alpha=1)

#3. Fit the vectorizer to get all of the quotes into the appropriate format
vectorizer.fit_transform(all_tweets.text)

#4. Make X, y for training sets 
X, y = make_xy(all_tweets, vectorizer)

# %%
#5. Fit the model to the transformed quotes
model.fit(X, y)

test_cut = test_cut.dropna()
testX = vectorizer.transform(test_cut.text)
testX = testX.tocsc()
testy = (test_cut['origin_x'] == 'real').values.astype(np.int)

model.score(testX, testy)

#Look at that! tfidf vectorizer is more effective at identifying twitter fakes than raw count vectorizer.
# Out:
# 0.8236103008584049

# %% [markdown]
# Random Forest Model, Same Data

# %%
#Now let's run a model with Random Forest to see if we can make an even more
#accurate set of predictions.
from sklearn.ensemble import RandomForestClassifier

# %%
#1. Initialize Classifier
clf = RandomForestClassifier(n_jobs=2, random_state=0)

#2. Fit to test X and y from tf-idf set
clf.fit(X, y)

#3. Predict on testX set
predictions = clf.predict(testX)

#4. Score 
clf.score(testX, testy)
# Out:
# 0.8474039503291941

# %%
#Parameters for optimal model
clf
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=2,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %% [markdown]
# 84.7% with unmodified parameters

# %%
#Now let's try some hyperparameter tuning. 
#Set up grid of possible hyperparameters

from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [500]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [2, 5, 8, 12, 20, 40]


# Minimum number of samples required at each leaf node

min_samples_leaf = [2, 5, 10, 20, 40, 80,160,320]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(random_grid)
# Out:
# {'n_estimators': [500], 'max_features': ['auto', 'sqrt'], 'max_depth': [2, 5, 8, 12, 20, 40], 'min_samples_leaf': [2, 5, 10, 20, 40, 80, 160, 320], 'bootstrap': [True, False]}

# %%
#Random Search model training 

# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestClassifier()
# Random search of parameters, using 5 fold cross validation, 
# search across 100 different combinations, and use all available cores

#1 Establish Model 
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 25, cv = 5, verbose=2, random_state=42, n_jobs = -1)

# %%
#2 Fit the random search model to the data
rf_random.fit(X,y)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:  7.6min finished
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#           fit_params=None, iid=True, n_iter=25, n_jobs=-1,
#           param_distributions={'n_estimators': [500], 'max_features': ['auto', 'sqrt'], 'max_depth': [2, 5, 8, 12, 20, 40], 'min_samples_leaf': [2, 5, 10, 20, 40, 80, 160, 320], 'bootstrap': [True, False]},
#           pre_dispatch='2*n_jobs', random_state=42, refit=True,
#           return_train_score='warn', scoring=None, verbose=2)

# %%
# Determine best parameters from the grid and training data
rf_random.best_params_
# Out:
# {'n_estimators': 500,
#  'min_samples_leaf': 5,
#  'max_features': 'auto',
#  'max_depth': 40,
#  'bootstrap': False}

# %%
#3. Predict on testX set
predictions = rf_random.predict(testX)

#4. Score 
rf_random.score(testX, testy)
# Out:
# 0.7273106092174347

# %% [markdown]
# Despite tweaking the model and optimizing for best parameters, our best random forest model still performs worse than our worst
# Naive Bayes Model

# %%
#1.
clf = RandomForestClassifier(n_jobs=2, min_samples_leaf=5, random_state=42, n_estimators=500, max_depth=40, bootstrap=False)
#2.
clf.fit(X,y)
#3. 
clf.predict(testX)
#4.
clf.score(testX,testy)
# Out:
# 0.7301441786815568

# %% [markdown]
# Random Forest Classifier with all variables, including NLP

# %%
# Merge the columns together 

import scipy.sparse 

#training set 

m = X
a = all_tweets[['followers_count', 'friends_count', 'statuses_count', 'num_hashtags','num_urls','num_mentions']]

#do the same for the test set - 

m_test = testX
a_test = test_cut[['followers_count', 'friends_count', 'statuses_count', 'num_hashtags','num_urls','num_mentions']]

X_merged = scipy.sparse.hstack((a,m))
X_test_merged = scipy.sparse.hstack((a_test, m_test))

# %%
trainX = vectorizer.transform(a)
trainX = trainX.tocsc()
trainy = (all_tweets['origin_x'] == 'real').values.astype(np.int)

# %%
#Fake lines -> leave in maybe, but remove line 99 for final presentation

testX = vectorizer.transform(a_test)
testX = testX.tocsc()
testy = (test_cut['origin_x'] == 'real').values.astype(np.int)

# %%
#Take X_merged, X_test_merged to make XY/training sets then run model again

testX = vectorizer.transform(test_cut.text)
testX = testX.tocsc()
testy = (test_cut['origin_x'] == 'real').values.astype(np.int)

# %%
#1. Initialize Classifier
clf = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini', max_depth=None, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=2, oob_score=False, random_state=0, verbose=0, warm_start=False)

#2. Fit to test X and y from tf-idf set
clf.fit(X, y)

#3. Predict on testX set
predictions = clf.predict(testX)

#4. Score 
clf.score(testX, testy)
# Out:
# 0.8349228475910053

# %% [markdown]
# #----------------------------------------------- Feature importances, etc. -----------------------------------------------------

# %%
#Let's digest the importances of these variables. 

importances = list(clf.feature_importances_)


feature_list = list(tfidf.get_feature_names())

feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]

features = np.array(features)

# %%
# Define top features

Xtrain = tfidf.fit_transform(all_tweets["text"])
y = all_tweets["origin_x"]
features = tfidf.get_feature_names()
top_dfs = top_feats_by_class(Xtrain, y, features)
# Out:
# C:\Users\cct51\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\cct51\Anaconda3\lib\site-packages\numpy\core\_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %%
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# %%
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: cab                  Importance: 0.02
# Variable: furry                Importance: 0.02
# Variable: heyy                 Importance: 0.02
# Variable: lily                 Importance: 0.02
# Variable: passenger            Importance: 0.02
# Variable: cease                Importance: 0.01
# Variable: corner               Importance: 0.01
# Variable: fratelli             Importance: 0.01
# Variable: fratello             Importance: 0.01
# Variable: glielo               Importance: 0.01
# Variable: inglese              Importance: 0.01
# Variable: pilatesandgin        Importance: 0.01
# Variable: preliminari          Importance: 0.01
# Variable: 00                   Importance: 0.0
# Variable: 000                  Importance: 0.0
# Variable: 01                   Importance: 0.0
# Variable: 02                   Importance: 0.0
# Variable: 03                   Importance: 0.0
# Variable: 04                   Importance: 0.0
# Variable: 05                   Importance: 0.0
# Variable: 06                   Importance: 0.0
# Variable: 07                   Importance: 0.0
# Variable: 08                   Importance: 0.0
# Variable: 09                   Importance: 0.0
# Variable: 10                   Importance: 0.0
# Variable: 100                  Importance: 0.0
# Variable: 1000                 Importance: 0.0
# Variable: 101                  Importance: 0.0
# Variable: 103                  Importance: 0.0
# Variable: 10pm                 Importance: 0.0
# Variable: 10th                 Importance: 0.0
# Variable: 11                   Importance: 0.0
# Variable: 113                  Importance: 0.0
# Variable: 12                   Importance: 0.0
# Variable: 120                  Importance: 0.0
# Variable: 13                   Importance: 0.0
# Variable: 130                  Importance: 0.0
# Variable: 13th                 Importance: 0.0
# Variable: 14                   Importance: 0.0
# Variable: 140                  Importance: 0.0
# Variable: 15                   Importance: 0.0
# Variable: 150                  Importance: 0.0
# Variable: 1582                 Importance: 0.0
# Variable: 16                   Importance: 0.0
# Variable: 160                  Importance: 0.0
# Variable: 16th                 Importance: 0.0
# Variable: 17                   Importance: 0.0
# Variable: 18                   Importance: 0.0
# Variable: 182                  Importance: 0.0
# Variable: 1861                 Importance: 0.0
# Variable: 1864                 Importance: 0.0
# Variable: 19                   Importance: 0.0
# Variable: 1912                 Importance: 0.0
# Variable: 1918                 Importance: 0.0
# Variable: 1919                 Importance: 0.0
# Variable: 1929                 Importance: 0.0
# Variable: 1933                 Importance: 0.0
# Variable: 1935                 Importance: 0.0
# Variable: 1938                 Importance: 0.0
# Variable: 1941                 Importance: 0.0
# Variable: 1942                 Importance: 0.0
# Variable: 1943                 Importance: 0.0
# Variable: 1944                 Importance: 0.0
# Variable: 1945                 Importance: 0.0
# Variable: 1949                 Importance: 0.0
# Variable: 1957                 Importance: 0.0
# Variable: 1960                 Importance: 0.0
# Variable: 1962                 Importance: 0.0
# Variable: 1964                 Importance: 0.0
# Variable: 1967                 Importance: 0.0
# Variable: 1968                 Importance: 0.0
# Variable: 1969                 Importance: 0.0
# Variable: 1970                 Importance: 0.0
# Variable: 1971                 Importance: 0.0
# Variable: 1972                 Importance: 0.0
# Variable: 1976                 Importance: 0.0
# Variable: 1977                 Importance: 0.0
# Variable: 1980                 Importance: 0.0
# Variable: 1984                 Importance: 0.0
# Variable: 1985                 Importance: 0.0
# Variable: 1987                 Importance: 0.0
# Variable: 1989                 Importance: 0.0
# Variable: 1990                 Importance: 0.0
# Variable: 1991                 Importance: 0.0
# Variable: 1992                 Importance: 0.0
# Variable: 1993                 Importance: 0.0
# Variable: 1994                 Importance: 0.0
# Variable: 1995                 Importance: 0.0
# Variable: 1998                 Importance: 0.0
# Variable: 1999                 Importance: 0.0
# Variable: 19th                 Importance: 0.0
# Variable: 1d                   Importance: 0.0
# Variable: 1d_forcaity          Importance: 0.0
# Variable: 1dupdatesonline      Importance: 0.0
# Variable: 1st                  Importance: 0.0
# Variable: 20                   Importance: 0.0
# Variable: 200                  Importance: 0.0
# Variable: 2000                 Importance: 0.0
# Variable: 2001                 Importance: 0.0
# Variable: 2002                 Importance: 0.0
# Variable: 2003                 Importance: 0.0
# Variable: 2004                 Importance: 0.0
# Variable: 2005                 Importance: 0.0
# Variable: 2006                 Importance: 0.0
# Variable: 2007                 Importance: 0.0
# Variable: 2008                 Importance: 0.0
# Variable: 2009                 Importance: 0.0
# Variable: 2010                 Importance: 0.0
# Variable: 2011                 Importance: 0.0
# Variable: 2012                 Importance: 0.0
# Variable: 2013                 Importance: 0.0
# Variable: 2014                 Importance: 0.0
# Variable: 2015                 Importance: 0.0
# Variable: 2016                 Importance: 0.0
# Variable: 2020                 Importance: 0.0
# Variable: 21                   Importance: 0.0
# Variable: 22                   Importance: 0.0
# Variable: 23                   Importance: 0.0
# Variable: 24                   Importance: 0.0
# Variable: 240                  Importance: 0.0
# Variable: 247                  Importance: 0.0
# Variable: 25                   Importance: 0.0
# Variable: 250                  Importance: 0.0
# Variable: 26                   Importance: 0.0
# Variable: 27                   Importance: 0.0
# Variable: 28                   Importance: 0.0
# Variable: 29                   Importance: 0.0
# Variable: 2nd                  Importance: 0.0
# Variable: 2x                   Importance: 0.0
# Variable: 30                   Importance: 0.0
# Variable: 300                  Importance: 0.0
# Variable: 30pm                 Importance: 0.0
# Variable: 31                   Importance: 0.0
# Variable: 32                   Importance: 0.0
# Variable: 33                   Importance: 0.0
# Variable: 333                  Importance: 0.0
# Variable: 34                   Importance: 0.0
# Variable: 35                   Importance: 0.0
# Variable: 353                  Importance: 0.0
# Variable: 36                   Importance: 0.0
# Variable: 360                  Importance: 0.0
# Variable: 365                  Importance: 0.0
# Variable: 37                   Importance: 0.0
# Variable: 38                   Importance: 0.0
# Variable: 39                   Importance: 0.0
# Variable: 3a                   Importance: 0.0
# Variable: 3d                   Importance: 0.0
# Variable: 3g                   Importance: 0.0
# Variable: 3mesi                Importance: 0.0
# Variable: 3pm                  Importance: 0.0
# Variable: 3rd                  Importance: 0.0
# Variable: 40                   Importance: 0.0
# Variable: 400                  Importance: 0.0
# Variable: 41                   Importance: 0.0
# Variable: 42                   Importance: 0.0
# Variable: 420                  Importance: 0.0
# Variable: 43                   Importance: 0.0
# Variable: 432                  Importance: 0.0
# Variable: 44                   Importance: 0.0
# Variable: 45                   Importance: 0.0
# Variable: 45pm                 Importance: 0.0
# Variable: 46                   Importance: 0.0
# Variable: 47                   Importance: 0.0
# Variable: 47enne               Importance: 0.0
# Variable: 48                   Importance: 0.0
# Variable: 49                   Importance: 0.0
# Variable: 49ers                Importance: 0.0
# Variable: 4a_i94               Importance: 0.0
# Variable: 4f6iyfyx             Importance: 0.0
# Variable: 4h                   Importance: 0.0
# Variable: 4ms                  Importance: 0.0
# Variable: 4s                   Importance: 0.0
# Variable: 4th                  Importance: 0.0
# Variable: 4го                  Importance: 0.0
# Variable: 4с                   Importance: 0.0
# Variable: 50                   Importance: 0.0
# Variable: 500                  Importance: 0.0
# Variable: 5000                 Importance: 0.0
# Variable: 500aday              Importance: 0.0
# Variable: 50cent               Importance: 0.0
# Variable: 51                   Importance: 0.0
# Variable: 52                   Importance: 0.0
# Variable: 53                   Importance: 0.0
# Variable: 54                   Importance: 0.0
# Variable: 55                   Importance: 0.0
# Variable: 56                   Importance: 0.0
# Variable: 57                   Importance: 0.0
# Variable: 57wk4z0uex           Importance: 0.0
# Variable: 58                   Importance: 0.0
# Variable: 59                   Importance: 0.0
# Variable: 5a                   Importance: 0.0
# Variable: 5isis                Importance: 0.0
# Variable: 5sos                 Importance: 0.0
# Variable: 5th                  Importance: 0.0
# Variable: 60                   Importance: 0.0
# Variable: 600                  Importance: 0.0
# Variable: 61                   Importance: 0.0
# Variable: 62                   Importance: 0.0
# Variable: 63                   Importance: 0.0
# Variable: 64                   Importance: 0.0
# Variable: 65                   Importance: 0.0
# Variable: 66                   Importance: 0.0
# Variable: 68                   Importance: 0.0
# Variable: 69                   Importance: 0.0
# Variable: 6pm                  Importance: 0.0
# Variable: 6th                  Importance: 0.0
# Variable: 70                   Importance: 0.0
# Variable: 700                  Importance: 0.0
# Variable: 72                   Importance: 0.0
# Variable: 73                   Importance: 0.0
# Variable: 75                   Importance: 0.0
# Variable: 78                   Importance: 0.0
# Variable: 79                   Importance: 0.0
# Variable: 7am                  Importance: 0.0
# Variable: 7d                   Importance: 0.0
# Variable: 7pm                  Importance: 0.0
# Variable: 7th                  Importance: 0.0
# Variable: 7tmartins            Importance: 0.0
# Variable: 80                   Importance: 0.0
# Variable: 800                  Importance: 0.0
# Variable: 805                  Importance: 0.0
# Variable: 805foodie            Importance: 0.0
# Variable: 81                   Importance: 0.0
# Variable: 84                   Importance: 0.0
# Variable: 85                   Importance: 0.0
# Variable: 86                   Importance: 0.0
# Variable: 88                   Importance: 0.0
# Variable: 89                   Importance: 0.0
# Variable: 8pm                  Importance: 0.0
# Variable: 8th                  Importance: 0.0
# Variable: 90                   Importance: 0.0
# Variable: 900                  Importance: 0.0
# Variable: 90sareallthat        Importance: 0.0
# Variable: 90sareallthatforgot  Importance: 0.0
# Variable: 91                   Importance: 0.0
# Variable: 92                   Importance: 0.0
# Variable: 94                   Importance: 0.0
# Variable: 95                   Importance: 0.0
# Variable: 96                   Importance: 0.0
# Variable: 99                   Importance: 0.0
# Variable: 9gag                 Importance: 0.0
# Variable: 9th                  Importance: 0.0
# Variable: __                   Importance: 0.0
# Variable: ___                  Importance: 0.0
# Variable: ____                 Importance: 0.0
# Variable: _____                Importance: 0.0
# Variable: ___thottieboa        Importance: 0.0
# Variable: __leslierojas        Importance: 0.0
# Variable: __princesssse        Importance: 0.0
# Variable: _aarj                Importance: 0.0
# Variable: _amandammm           Importance: 0.0
# Variable: _andrio              Importance: 0.0
# Variable: _barca4ever_         Importance: 0.0
# Variable: _begreatjb           Importance: 0.0
# Variable: _briannaraye_        Importance: 0.0
# Variable: _itsmetif            Importance: 0.0
# Variable: _ksandraaaa          Importance: 0.0
# Variable: _padawanski          Importance: 0.0
# Variable: _simpleahmazing      Importance: 0.0
# Variable: _taylorbennett       Importance: 0.0
# Variable: _tooori              Importance: 0.0
# Variable: _ttinaa_             Importance: 0.0
# Variable: _yemimah             Importance: 0.0
# Variable: _yourlastkiss_       Importance: 0.0
# Variable: a_nicole77           Importance: 0.0
# Variable: aa                   Importance: 0.0
# Variable: aaa                  Importance: 0.0
# Variable: aah                  Importance: 0.0
# Variable: aahfeekiee           Importance: 0.0
# Variable: aamory_1000          Importance: 0.0
# Variable: aan                  Importance: 0.0
# Variable: ab                   Importance: 0.0
# Variable: abbaia               Importance: 0.0
# Variable: abbandonare          Importance: 0.0
# Variable: abbandoni            Importance: 0.0
# Variable: abbassata            Importance: 0.0
# Variable: abbassi              Importance: 0.0
# Variable: abbastanza           Importance: 0.0
# Variable: abbi                 Importance: 0.0
# Variable: abbi_buchan          Importance: 0.0
# Variable: abbia                Importance: 0.0
# Variable: abbiamo              Importance: 0.0
# Variable: abbiano              Importance: 0.0
# Variable: abbiate              Importance: 0.0
# Variable: abbonamento          Importance: 0.0
# Variable: abbondanza           Importance: 0.0
# Variable: abbracci             Importance: 0.0
# Variable: abbraccio            Importance: 0.0
# Variable: abc                  Importance: 0.0
# Variable: abc7                 Importance: 0.0
# Variable: abdashsoul           Importance: 0.0
# Variable: abdominal            Importance: 0.0
# Variable: abigenbupar          Importance: 0.0
# Variable: abili                Importance: 0.0
# Variable: abilities            Importance: 0.0
# Variable: ability              Importance: 0.0
# Variable: abilità              Importance: 0.0
# Variable: abis                 Importance: 0.0
# Variable: abiti                Importance: 0.0
# Variable: abito                Importance: 0.0
# Variable: abituarti            Importance: 0.0
# Variable: abitudinaria         Importance: 0.0
# Variable: abitudine            Importance: 0.0
# Variable: able                 Importance: 0.0
# Variable: abortion             Importance: 0.0
# Variable: about                Importance: 0.0
# Variable: above                Importance: 0.0
# Variable: abraham              Importance: 0.0
# Variable: abramxjosiah         Importance: 0.0
# Variable: abrazo               Importance: 0.0
# Variable: abri                 Importance: 0.0
# Variable: abs                  Importance: 0.0
# Variable: absolute             Importance: 0.0
# Variable: absolutely           Importance: 0.0
# Variable: abt                  Importance: 0.0
# Variable: abundant             Importance: 0.0
# Variable: abuse                Importance: 0.0
# Variable: ac                   Importance: 0.0
# Variable: acaba                Importance: 0.0
# Variable: acabando             Importance: 0.0
# Variable: acabei               Importance: 0.0
# Variable: acabo                Importance: 0.0
# Variable: accaddeoggi          Importance: 0.0
# Variable: accade               Importance: 0.0
# Variable: accadrà              Importance: 0.0
# Variable: accanto              Importance: 0.0
# Variable: accantonalo          Importance: 0.0
# Variable: accarezzare          Importance: 0.0
# Variable: accendere            Importance: 0.0
# Variable: accendo              Importance: 0.0
# Variable: accent               Importance: 0.0
# Variable: accept               Importance: 0.0
# Variable: acceptance           Importance: 0.0
# Variable: accepted             Importance: 0.0
# Variable: accepting            Importance: 0.0
# Variable: access               Importance: 0.0
# Variable: accesso              Importance: 0.0
# Variable: accetta              Importance: 0.0
# Variable: accettare            Importance: 0.0
# Variable: accettazione         Importance: 0.0
# Variable: accetto              Importance: 0.0
# Variable: accident             Importance: 0.0
# Variable: accidentally         Importance: 0.0
# Variable: accoglie             Importance: 0.0
# Variable: accomodanti          Importance: 0.0
# Variable: accompagnato         Importance: 0.0
# Variable: according            Importance: 0.0
# Variable: accordo              Importance: 0.0
# Variable: accorge              Importance: 0.0
# Variable: accorgermi           Importance: 0.0
# Variable: accorgersi           Importance: 0.0
# Variable: accorgi              Importance: 0.0
# Variable: accorto              Importance: 0.0
# Variable: account              Importance: 0.0
# Variable: accounts             Importance: 0.0
# Variable: accresce             Importance: 0.0
# Variable: accumulate           Importance: 0.0
# Variable: accurate             Importance: 0.0
# Variable: accused              Importance: 0.0
# Variable: acdc                 Importance: 0.0
# Variable: acentodiario         Importance: 0.0
# Variable: acheson              Importance: 0.0
# Variable: achieve              Importance: 0.0
# Variable: achievement          Importance: 0.0
# Variable: acho                 Importance: 0.0
# Variable: acido                Importance: 0.0
# Variable: acm                  Importance: 0.0
# Variable: acmawards            Importance: 0.0
# Variable: acqua                Importance: 0.0
# Variable: acquista             Importance: 0.0
# Variable: across               Importance: 0.0
# Variable: act                  Importance: 0.0
# Variable: acting               Importance: 0.0
# Variable: action               Importance: 0.0
# Variable: actions              Importance: 0.0
# Variable: active               Importance: 0.0
# Variable: activists            Importance: 0.0
# Variable: activities           Importance: 0.0
# Variable: activity             Importance: 0.0
# Variable: actor                Importance: 0.0
# Variable: acts                 Importance: 0.0
# Variable: actual               Importance: 0.0
# Variable: actually             Importance: 0.0
# Variable: acustico             Importance: 0.0
# Variable: ad                   Importance: 0.0
# Variable: ada                  Importance: 0.0
# Variable: adaaleneee           Importance: 0.0
# Variable: adalah               Importance: 0.0
# Variable: adam                 Importance: 0.0
# Variable: adamdrakeonair       Importance: 0.0
# Variable: adamo                Importance: 0.0
# Variable: adams                Importance: 0.0
# Variable: add                  Importance: 0.0
# Variable: addawordruinamovie   Importance: 0.0
# Variable: added                Importance: 0.0
# Variable: addice               Importance: 0.0
# Variable: addicted             Importance: 0.0
# Variable: addicting            Importance: 0.0
# Variable: addiction            Importance: 0.0
# Variable: addio                Importance: 0.0
# Variable: addirittura          Importance: 0.0
# Variable: addition             Importance: 0.0
# Variable: addosso              Importance: 0.0
# Variable: address              Importance: 0.0
# Variable: adds                 Importance: 0.0
# Variable: addthis              Importance: 0.0
# Variable: ade                  Importance: 0.0
# Variable: adele                Importance: 0.0
# Variable: adesso               Importance: 0.0
# Variable: adgpi                Importance: 0.0
# Variable: adianta              Importance: 0.0
# Variable: adler                Importance: 0.0
# Variable: admin                Importance: 0.0
# Variable: admit                Importance: 0.0
# Variable: adobe                Importance: 0.0
# Variable: adolescenti          Importance: 0.0
# Variable: adolf                Importance: 0.0
# Variable: adora                Importance: 0.0
# Variable: adorable             Importance: 0.0
# Variable: adoro                Importance: 0.0
# Variable: adotta               Importance: 0.0
# Variable: adrien               Importance: 0.0
# Variable: ads                  Importance: 0.0
# Variable: aduh                 Importance: 0.0
# Variable: adult                Importance: 0.0
# Variable: adulti               Importance: 0.0
# Variable: adults               Importance: 0.0
# Variable: advance              Importance: 0.0
# Variable: advanced             Importance: 0.0
# Variable: advertising          Importance: 0.0
# Variable: advice               Importance: 0.0
# Variable: ae                   Importance: 0.0
# Variable: aeoroporto           Importance: 0.0
# Variable: aereo                Importance: 0.0
# Variable: af                   Importance: 0.0
# Variable: aff                  Importance: 0.0
# Variable: affair               Importance: 0.0
# Variable: affairs              Importance: 0.0
# Variable: affamati             Importance: 0.0
# Variable: affamato             Importance: 0.0
# Variable: affanculo            Importance: 0.0
# Variable: affare               Importance: 0.0
# Variable: affari               Importance: 0.0
# Variable: affascina            Importance: 0.0
# Variable: affascinanti         Importance: 0.0
# Variable: affatto              Importance: 0.0
# Variable: affected             Importance: 0.0
# Variable: affetto              Importance: 0.0
# Variable: affiliated           Importance: 0.0
# Variable: affinché             Importance: 0.0
# Variable: affinità             Importance: 0.0
# Variable: affogare             Importance: 0.0
# Variable: affogherò            Importance: 0.0
# Variable: affondato            Importance: 0.0
# Variable: afford               Importance: 0.0
# Variable: affordable           Importance: 0.0
# Variable: affronta             Importance: 0.0
# Variable: affrontare           Importance: 0.0
# Variable: afghanistan          Importance: 0.0
# Variable: aforismi             Importance: 0.0
# Variable: afraid               Importance: 0.0
# Variable: africa               Importance: 0.0
# Variable: african              Importance: 0.0
# Variable: afspeellijst         Importance: 0.0
# Variable: after                Importance: 0.0
# Variable: afternoon            Importance: 0.0
# Variable: ag                   Importance: 0.0
# Variable: agad                 Importance: 0.0
# Variable: again                Importance: 0.0
# Variable: against              Importance: 0.0
# Variable: age                  Importance: 0.0
# Variable: aged                 Importance: 0.0
# Variable: agency               Importance: 0.0
# Variable: agenda               Importance: 0.0
# Variable: agent                Importance: 0.0
# Variable: agente               Importance: 0.0
# Variable: ages                 Importance: 0.0
# Variable: aggies               Importance: 0.0
# Variable: aggiunge             Importance: 0.0
# Variable: aggiungere           Importance: 0.0
# Variable: agh                  Importance: 0.0
# Variable: agire                Importance: 0.0
# Variable: agisce               Importance: 0.0
# Variable: agli                 Importance: 0.0
# Variable: agnes_kim            Importance: 0.0
# Variable: ago                  Importance: 0.0
# Variable: agora                Importance: 0.0
# Variable: agostino             Importance: 0.0
# Variable: agosto               Importance: 0.0
# Variable: agr                  Importance: 0.0
# Variable: agree                Importance: 0.0
# Variable: agreed               Importance: 0.0
# Variable: agricoltura          Importance: 0.0
# Variable: agua                 Importance: 0.0
# Variable: aguardem             Importance: 0.0
# Variable: ah                   Importance: 0.0
# Variable: aha                  Importance: 0.0
# Variable: ahahah               Importance: 0.0
# Variable: ahahaha              Importance: 0.0
# Variable: ahdozenroses         Importance: 0.0
# Variable: ahead                Importance: 0.0
# Variable: ahh                  Importance: 0.0
# Variable: ahhh                 Importance: 0.0
# Variable: ahhhh                Importance: 0.0
# Variable: ahi                  Importance: 0.0
# Variable: aho                  Importance: 0.0
# Variable: ahora                Importance: 0.0
# Variable: ai                   Importance: 0.0
# Variable: aiai                 Importance: 0.0
# Variable: aid                  Importance: 0.0
# Variable: aids                 Importance: 0.0
# Variable: aii                  Importance: 0.0
# Variable: aillavyou101         Importance: 0.0
# Variable: aim                  Importance: 0.0
# Variable: ain                  Importance: 0.0
# Variable: ainda                Importance: 0.0
# Variable: aint                 Importance: 0.0
# Variable: air                  Importance: 0.0
# Variable: aircraft             Importance: 0.0
# Variable: airlines             Importance: 0.0
# Variable: airlivenet           Importance: 0.0
# Variable: airplane             Importance: 0.0
# Variable: airport              Importance: 0.0
# Variable: aiuta                Importance: 0.0
# Variable: aiutare              Importance: 0.0
# Variable: aiutarmi             Importance: 0.0
# Variable: aiuti                Importance: 0.0
# Variable: aiuto                Importance: 0.0
# Variable: aja                  Importance: 0.0
# Variable: ajuda                Importance: 0.0
# Variable: aka                  Importance: 0.0
# Variable: akan                 Importance: 0.0
# Variable: akdaxger33           Importance: 0.0
# Variable: akhirnya             Importance: 0.0
# Variable: aki                  Importance: 0.0
# Variable: ako                  Importance: 0.0
# Variable: akong                Importance: 0.0
# Variable: aku                  Importance: 0.0
# Variable: al                   Importance: 0.0
# Variable: alabama              Importance: 0.0
# Variable: alam                 Importance: 0.0
# Variable: alan                 Importance: 0.0
# Variable: alananana_           Importance: 0.0
# Variable: alanhungover         Importance: 0.0
# Variable: alarm                Importance: 0.0
# Variable: alba                 Importance: 0.0
# Variable: alberi               Importance: 0.0
# Variable: albero               Importance: 0.0
# Variable: albert               Importance: 0.0
# Variable: alberto              Importance: 0.0
# Variable: alberto_wstx         Importance: 0.0
# Variable: album                Importance: 0.0
# Variable: albums               Importance: 0.0
# Variable: alcohol              Importance: 0.0
# Variable: alcol                Importance: 0.0
# Variable: alcool               Importance: 0.0
# Variable: alcun                Importance: 0.0
# Variable: alcuna               Importance: 0.0
# Variable: alcune               Importance: 0.0
# Variable: alcuni               Importance: 0.0
# Variable: aldous               Importance: 0.0
# Variable: alejandro            Importance: 0.0
# Variable: aleksvrteski         Importance: 0.0
# Variable: alert                Importance: 0.0
# Variable: alessandra           Importance: 0.0
# Variable: alessandro           Importance: 0.0
# Variable: alessio              Importance: 0.0
# Variable: alex                 Importance: 0.0
# Variable: alexisakerly         Importance: 0.0
# Variable: alfano               Importance: 0.0
# Variable: alfieri              Importance: 0.0
# Variable: algo                 Importance: 0.0
# Variable: alguem               Importance: 0.0
# Variable: alguien              Importance: 0.0
# Variable: alguma               Importance: 0.0
# Variable: alguna               Importance: 0.0
# Variable: alguns               Importance: 0.0
# Variable: alguém               Importance: 0.0
# Variable: alhamdulillah        Importance: 0.0
# Variable: ali                  Importance: 0.0
# Variable: alibi                Importance: 0.0
# Variable: aliceonthefloor      Importance: 0.0
# Variable: alicerobertsonx      Importance: 0.0
# Variable: alighieri            Importance: 0.0
# Variable: alito                Importance: 0.0
# Variable: alive                Importance: 0.0
# Variable: all                  Importance: 0.0
# Variable: alla                 Importance: 0.0
# Variable: allah                Importance: 0.0
# Variable: allan                Importance: 0.0
# Variable: allarme              Importance: 0.0
# Variable: alle                 Importance: 0.0
# Variable: alleen               Importance: 0.0
# Variable: alleged              Importance: 0.0
# Variable: allegria             Importance: 0.0
# Variable: allemaal             Importance: 0.0
# Variable: allen                Importance: 0.0
# Variable: allenatore           Importance: 0.0
# Variable: allieroseknows       Importance: 0.0
# Variable: allievo              Importance: 0.0
# Variable: alliswelljeruel      Importance: 0.0
# Variable: allo                 Importance: 0.0
# Variable: allora               Importance: 0.0
# Variable: allow                Importance: 0.0
# Variable: allowed              Importance: 0.0
# Variable: allowing             Importance: 0.0
# Variable: allows               Importance: 0.0
# Variable: allucinazioni        Importance: 0.0
# Variable: alma                 Importance: 0.0
# Variable: almeno               Importance: 0.0
# Variable: almost               Importance: 0.0
# Variable: alone                Importance: 0.0
# Variable: along                Importance: 0.0
# Variable: alot                 Importance: 0.0
# Variable: alphen               Importance: 0.0
# Variable: alphonse             Importance: 0.0
# Variable: already              Importance: 0.0
# Variable: alright              Importance: 0.0
# Variable: als                  Importance: 0.0
# Variable: also                 Importance: 0.0
# Variable: alt                  Importance: 0.0
# Variable: alta                 Importance: 0.0
# Variable: altan                Importance: 0.0
# Variable: alte                 Importance: 0.0
# Variable: alterloki            Importance: 0.0
# Variable: alternativa          Importance: 0.0
# Variable: alternative          Importance: 0.0
# Variable: altezza              Importance: 0.0
# Variable: although             Importance: 0.0
# Variable: alti                 Importance: 0.0
# Variable: altijd               Importance: 0.0
# Variable: alto                 Importance: 0.0
# Variable: altra                Importance: 0.0
# Variable: altre                Importance: 0.0
# Variable: altrettanto          Importance: 0.0
# Variable: altri                Importance: 0.0
# Variable: altrimenti           Importance: 0.0
# Variable: altro                Importance: 0.0
# Variable: altrove              Importance: 0.0
# Variable: altrui               Importance: 0.0
# Variable: alvaro               Importance: 0.0
# Variable: always               Importance: 0.0
# Variable: alza                 Importance: 0.0
# Variable: alzare               Importance: 0.0
# Variable: alzarmi              Importance: 0.0
# Variable: alzarsi              Importance: 0.0
# Variable: alzato               Importance: 0.0
# Variable: alzheimer            Importance: 0.0
# Variable: alzi                 Importance: 0.0
# Variable: alzo                 Importance: 0.0
# Variable: além                 Importance: 0.0
# Variable: am                   Importance: 0.0
# Variable: ama                  Importance: 0.0
# Variable: amabile              Importance: 0.0
# Variable: amabili              Importance: 0.0
# Variable: amami                Importance: 0.0
# Variable: amanha               Importance: 0.0
# Variable: amanhã               Importance: 0.0
# Variable: amano                Importance: 0.0
# Variable: amante               Importance: 0.0
# Variable: amanti               Importance: 0.0
# Variable: amar                 Importance: 0.0
# Variable: amare                Importance: 0.0
# Variable: amarmi               Importance: 0.0
# Variable: amaro                Importance: 0.0
# Variable: amarsi               Importance: 0.0
# Variable: amarvi               Importance: 0.0
# Variable: amat                 Importance: 0.0
# Variable: amati                Importance: 0.0
# Variable: amato                Importance: 0.0
# Variable: amazed               Importance: 0.0
# Variable: amazing              Importance: 0.0
# Variable: amazon               Importance: 0.0
# Variable: amazonauthorsprofile Importance: 0.0
# Variable: ambarbrito           Importance: 0.0
# Variable: ambassador           Importance: 0.0
# Variable: ambizione            Importance: 0.0
# Variable: ambizioni            Importance: 0.0
# Variable: ambiziosi            Importance: 0.0
# Variable: ambrose              Importance: 0.0
# Variable: amelia               Importance: 0.0
# Variable: amen                 Importance: 0.0
# Variable: amendment            Importance: 0.0
# Variable: ameratex             Importance: 0.0
# Variable: ameratexoil          Importance: 0.0
# Variable: america              Importance: 0.0
# Variable: american             Importance: 0.0
# Variable: americana            Importance: 0.0
# Variable: americani            Importance: 0.0
# Variable: americano            Importance: 0.0
# Variable: americans            Importance: 0.0
# Variable: ami                  Importance: 0.0
# Variable: amiamo               Importance: 0.0
# Variable: amica                Importance: 0.0
# Variable: amiche               Importance: 0.0
# Variable: amici                Importance: 0.0
# Variable: amicizia             Importance: 0.0
# Variable: amico                Importance: 0.0
# Variable: amiel                Importance: 0.0
# Variable: amiga                Importance: 0.0
# Variable: amigo                Importance: 0.0
# Variable: amigos               Importance: 0.0
# Variable: amin                 Importance: 0.0
# Variable: ammazzati            Importance: 0.0
# Variable: ammazzi              Importance: 0.0
# Variable: ammette              Importance: 0.0
# Variable: ammirazione          Importance: 0.0
# Variable: ammiro               Importance: 0.0
# Variable: amo                  Importance: 0.0
# Variable: amol                 Importance: 0.0
# Variable: among                Importance: 0.0
# Variable: amor                 Importance: 0.0
# Variable: amore                Importance: 0.0
# Variable: amoree               Importance: 0.0
# Variable: amores               Importance: 0.0
# Variable: amoreses             Importance: 0.0
# Variable: amori                Importance: 0.0
# Variable: amount               Importance: 0.0
# Variable: amp                  Importance: 0.0
# Variable: amr                  Importance: 0.0
# Variable: amsterdam            Importance: 0.0
# Variable: amy                  Importance: 0.0
# Variable: amò                  Importance: 0.0
# Variable: an                   Importance: 0.0
# Variable: ana                  Importance: 0.0
# Variable: anagramma            Importance: 0.0
# Variable: anais                Importance: 0.0
# Variable: anak                 Importance: 0.0
# Variable: analisarococo        Importance: 0.0
# Variable: analisi              Importance: 0.0
# Variable: analysis             Importance: 0.0
# Variable: anatole              Importance: 0.0
# Variable: anatomy              Importance: 0.0
# Variable: anatroccolo          Importance: 0.0
# Variable: anch                 Importance: 0.0
# Variable: anche                Importance: 0.0
# Variable: anchor               Importance: 0.0
# Variable: ancient              Importance: 0.0
# Variable: ancora               Importance: 0.0
# Variable: and                  Importance: 0.0
# Variable: anda                 Importance: 0.0
# Variable: andando              Importance: 0.0
# Variable: andar                Importance: 0.0
# Variable: andarci              Importance: 0.0
# Variable: andare               Importance: 0.0
# Variable: andata               Importance: 0.0
# Variable: andate               Importance: 0.0
# Variable: andati               Importance: 0.0
# Variable: andato               Importance: 0.0
# Variable: andava               Importance: 0.0
# Variable: anders               Importance: 0.0
# Variable: andiamo              Importance: 0.0
# Variable: andre                Importance: 0.0
# Variable: andrea               Importance: 0.0
# Variable: andrebbe             Importance: 0.0
# Variable: andrei               Importance: 0.0
# Variable: andreotti            Importance: 0.0
# Variable: andrew               Importance: 0.0
# Variable: andrewoddie          Importance: 0.0
# Variable: android              Importance: 0.0
# Variable: androidgames         Importance: 0.0
# Variable: andrà                Importance: 0.0
# Variable: andrè                Importance: 0.0
# Variable: andy                 Importance: 0.0
# Variable: anello               Importance: 0.0
# Variable: ang                  Importance: 0.0
# Variable: angel                Importance: 0.0
# Variable: angela               Importance: 0.0
# Variable: angeles              Importance: 0.0
# Variable: angelina             Importance: 0.0
# Variable: angelo               Importance: 0.0
# Variable: angelo_fierce        Importance: 0.0
# Variable: angels               Importance: 0.0
# Variable: angelsolis394        Importance: 0.0
# Variable: anger                Importance: 0.0
# Variable: angolo               Importance: 0.0
# Variable: angry                Importance: 0.0
# Variable: ani                  Importance: 0.0
# Variable: ani_news             Importance: 0.0
# Variable: anima                Importance: 0.0
# Variable: animal               Importance: 0.0
# Variable: animale              Importance: 0.0
# Variable: animali              Importance: 0.0
# Variable: animals              Importance: 0.0
# Variable: anime                Importance: 0.0
# Variable: animo                Importance: 0.0
# Variable: aniversario          Importance: 0.0
# Variable: aniversário          Importance: 0.0
# Variable: ann                  Importance: 0.0
# Variable: anna                 Importance: 0.0
# Variable: annarosa             Importance: 0.0
# Variable: annaylasolana        Importance: 0.0
# Variable: anne                 Importance: 0.0
# Variable: anneaam              Importance: 0.0
# Variable: anni                 Importance: 0.0
# Variable: annie                Importance: 0.0
# Variable: annieebellee         Importance: 0.0
# Variable: annieebw             Importance: 0.0
# Variable: annikins1d           Importance: 0.0
# Variable: anniversary          Importance: 0.0
# Variable: anno                 Importance: 0.0
# Variable: announce             Importance: 0.0
# Variable: announced            Importance: 0.0
# Variable: announcement         Importance: 0.0
# Variable: announces            Importance: 0.0
# Variable: annoyed              Importance: 0.0
# Variable: annoying             Importance: 0.0
# Variable: annuale              Importance: 0.0
# Variable: annunceremo          Importance: 0.0
# Variable: annuncia             Importance: 0.0
# Variable: annunciano           Importance: 0.0
# Variable: ano                  Importance: 0.0
# Variable: anonimo              Importance: 0.0
# Variable: anonymous            Importance: 0.0
# Variable: anos                 Importance: 0.0
# Variable: another              Importance: 0.0
# Variable: anshetabss           Importance: 0.0
# Variable: ansia                Importance: 0.0
# Variable: answer               Importance: 0.0
# Variable: answers              Importance: 0.0
# Variable: antebellum           Importance: 0.0
# Variable: antes                Importance: 0.0
# Variable: anthem               Importance: 0.0
# Variable: anthony              Importance: 0.0
# Variable: anti                 Importance: 0.0
# Variable: antica               Importance: 0.0
# Variable: anticamente          Importance: 0.0
# Variable: anticipo             Importance: 0.0
# Variable: antico               Importance: 0.0
# Variable: antifonte            Importance: 0.0
# Variable: antijokeapple        Importance: 0.0
# Variable: antipatico           Importance: 0.0
# Variable: antivirus            Importance: 0.0
# Variable: antonio              Importance: 0.0
# Variable: antonio_kills57      Importance: 0.0
# Variable: antzpantz            Importance: 0.0
# Variable: anupam               Importance: 0.0
# Variable: anupamkpandey        Importance: 0.0
# Variable: anxiety              Importance: 0.0
# Variable: any                  Importance: 0.0
# Variable: anybody              Importance: 0.0
# Variable: anymore              Importance: 0.0
# Variable: anyone               Importance: 0.0
# Variable: anything             Importance: 0.0
# Variable: anytime              Importance: 0.0
# Variable: anyway               Importance: 0.0
# Variable: anyways              Importance: 0.0
# Variable: anywhere             Importance: 0.0
# Variable: anziani              Importance: 0.0
# Variable: anziché              Importance: 0.0
# Variable: ao                   Importance: 0.0
# Variable: aos                  Importance: 0.0
# Variable: ap                   Importance: 0.0
# Variable: apa                  Importance: 0.0
# Variable: apart                Importance: 0.0
# Variable: apartment            Importance: 0.0
# Variable: ape                  Importance: 0.0
# Variable: apenas               Importance: 0.0
# Variable: aperitivo            Importance: 0.0
# Variable: aperta               Importance: 0.0
# Variable: aperte               Importance: 0.0
# Variable: aperti               Importance: 0.0
# Variable: aperto               Importance: 0.0
# Variable: aphillx3             Importance: 0.0
# Variable: api                  Importance: 0.0
# Variable: apologies            Importance: 0.0
# Variable: apologize            Importance: 0.0
# Variable: apology              Importance: 0.0
# Variable: apostoli             Importance: 0.0
# Variable: app                  Importance: 0.0
# Variable: appaiono             Importance: 0.0
# Variable: appannati            Importance: 0.0
# Variable: apparecchio          Importance: 0.0
# Variable: apparently           Importance: 0.0
# Variable: apparenza            Importance: 0.0
# Variable: apparenze            Importance: 0.0
# Variable: apparire             Importance: 0.0
# Variable: appassito            Importance: 0.0
# Variable: appear               Importance: 0.0
# Variable: appears              Importance: 0.0
# Variable: appello              Importance: 0.0
# Variable: appena               Importance: 0.0
# Variable: appesi               Importance: 0.0
# Variable: apple                Importance: 0.0
# Variable: appleslaps           Importance: 0.0
# Variable: applica              Importance: 0.0
# Variable: application          Importance: 0.0
# Variable: apply                Importance: 0.0
# Variable: appointment          Importance: 0.0
# Variable: appreciate           Importance: 0.0
# Variable: appreciation         Importance: 0.0
# Variable: apprezzano           Importance: 0.0
# Variable: apprezzare           Importance: 0.0
# Variable: approach             Importance: 0.0
# Variable: appropriate          Importance: 0.0
# Variable: apps                 Importance: 0.0
# Variable: appuntamento         Importance: 0.0
# Variable: appunto              Importance: 0.0
# Variable: apr                  Importance: 0.0
# Variable: apre                 Importance: 0.0
# Variable: aprender             Importance: 0.0
# Variable: apri                 Importance: 0.0
# Variable: april                Importance: 0.0
# Variable: aprile               Importance: 0.0
# Variable: aprire               Importance: 0.0
# Variable: aprirsi              Importance: 0.0
# Variable: apro                 Importance: 0.0
# Variable: aprono               Importance: 0.0
# Variable: apts                 Importance: 0.0
# Variable: aq                   Importance: 0.0
# Variable: aqui                 Importance: 0.0
# Variable: aquilo               Importance: 0.0
# Variable: ar                   Importance: 0.0
# Variable: arab                 Importance: 0.0
# Variable: arabia               Importance: 0.0
# Variable: arabic               Importance: 0.0
# Variable: arbitro              Importance: 0.0
# Variable: arca                 Importance: 0.0
# Variable: arcadia              Importance: 0.0
# Variable: architecture         Importance: 0.0
# Variable: arco                 Importance: 0.0
# Variable: arcobaleno           Importance: 0.0
# Variable: arctic               Importance: 0.0
# Variable: ardentemente         Importance: 0.0
# Variable: are                  Importance: 0.0
# Variable: area                 Importance: 0.0
# Variable: areas                Importance: 0.0
# Variable: aren                 Importance: 0.0
# Variable: argentina            Importance: 0.0
# Variable: argomento            Importance: 0.0
# Variable: argue                Importance: 0.0
# Variable: argument             Importance: 0.0
# Variable: ari_nellen           Importance: 0.0
# Variable: aria                 Importance: 0.0
# Variable: ariana               Importance: 0.0
# Variable: arielrebel           Importance: 0.0
# Variable: aristotele           Importance: 0.0
# Variable: arizona              Importance: 0.0
# Variable: arizonadot           Importance: 0.0
# Variable: arkham               Importance: 0.0
# Variable: arm                  Importance: 0.0
# Variable: arma                 Importance: 0.0
# Variable: armadio              Importance: 0.0
# Variable: armata               Importance: 0.0
# Variable: armi                 Importance: 0.0
# Variable: armonia              Importance: 0.0
# Variable: armor                Importance: 0.0
# Variable: arms                 Importance: 0.0
# Variable: armstrong            Importance: 0.0
# Variable: army                 Importance: 0.0
# Variable: arnout0172           Importance: 0.0
# Variable: around               Importance: 0.0
# Variable: arrabbiare           Importance: 0.0
# Variable: arrabbiata           Importance: 0.0
# Variable: arrabbiati           Importance: 0.0
# Variable: arrabbiato           Importance: 0.0
# Variable: arrest               Importance: 0.0
# Variable: arrestato            Importance: 0.0
# Variable: arrested             Importance: 0.0
# Variable: arriva               Importance: 0.0
# Variable: arrivano             Importance: 0.0
# Variable: arrivare             Importance: 0.0
# Variable: arrivata             Importance: 0.0
# Variable: arrivati             Importance: 0.0
# Variable: arrivato             Importance: 0.0
# Variable: arrive               Importance: 0.0
# Variable: arrived              Importance: 0.0
# Variable: arriverà             Importance: 0.0
# Variable: arrivi               Importance: 0.0
# Variable: arrivo               Importance: 0.0
# Variable: arrogant             Importance: 0.0
# Variable: arrogante            Importance: 0.0
# Variable: arrumar              Importance: 0.0
# Variable: arsenal              Importance: 0.0
# Variable: art                  Importance: 0.0
# Variable: arte                 Importance: 0.0
# Variable: artem_klyushin       Importance: 0.0
# Variable: arthur               Importance: 0.0
# Variable: article              Importance: 0.0
# Variable: articles             Importance: 0.0
# Variable: articolo             Importance: 0.0
# Variable: artist               Importance: 0.0
# Variable: artista              Importance: 0.0
# Variable: artists              Importance: 0.0
# Variable: arturo               Importance: 0.0
# Variable: as                   Importance: 0.0
# Variable: asa                  Importance: 0.0
# Variable: asap                 Importance: 0.0
# Variable: ascensore            Importance: 0.0
# Variable: ascolta              Importance: 0.0
# Variable: ascoltano            Importance: 0.0
# Variable: ascoltare            Importance: 0.0
# Variable: ascoltato            Importance: 0.0
# Variable: ascolti              Importance: 0.0
# Variable: asf                  Importance: 0.0
# Variable: ash_nichole940       Importance: 0.0
# Variable: ashton               Importance: 0.0
# Variable: ashton5sos           Importance: 0.0
# Variable: ashtonalford23       Importance: 0.0
# Variable: asi                  Importance: 0.0
# Variable: asia                 Importance: 0.0
# Variable: asian                Importance: 0.0
# Variable: asianinvasion54      Importance: 0.0
# Variable: asilo                Importance: 0.0
# Variable: ask                  Importance: 0.0
# Variable: asked                Importance: 0.0
# Variable: asking               Importance: 0.0
# Variable: asks                 Importance: 0.0
# Variable: asl                  Importance: 0.0
# Variable: asleep               Importance: 0.0
# Variable: asmoore              Importance: 0.0
# Variable: aspen_liz            Importance: 0.0
# Variable: aspetta              Importance: 0.0
# Variable: aspettando           Importance: 0.0
# Variable: aspettano            Importance: 0.0
# Variable: aspettare            Importance: 0.0
# Variable: aspettarsi           Importance: 0.0
# Variable: aspettate            Importance: 0.0
# Variable: aspettative          Importance: 0.0
# Variable: aspettavo            Importance: 0.0
# Variable: aspetti              Importance: 0.0
# ...
# Variable: suspended            Importance: 0.0
# Variable: suttapitaka          Importance: 0.0
# Variable: suv                  Importance: 0.0
# Variable: svaligiato           Importance: 0.0
# Variable: svanisce             Importance: 0.0
# Variable: svegli               Importance: 0.0
# Variable: sveglia              Importance: 0.0
# Variable: svegliarmi           Importance: 0.0
# Variable: svegliarsi           Importance: 0.0
# Variable: svegliati            Importance: 0.0
# Variable: sveglio              Importance: 0.0
# Variable: sveltina             Importance: 0.0
# Variable: svezia               Importance: 0.0
# Variable: svolge               Importance: 0.0
# Variable: swachhbharat         Importance: 0.0
# Variable: swag                 Importance: 0.0
# Variable: swear                Importance: 0.0
# Variable: sweater              Importance: 0.0
# Variable: sweating             Importance: 0.0
# Variable: sweeet               Importance: 0.0
# Variable: sweet                Importance: 0.0
# Variable: sweetevaxx           Importance: 0.0
# Variable: sweetie              Importance: 0.0
# Variable: sweety               Importance: 0.0
# Variable: swift                Importance: 0.0
# Variable: swiftonsecurity      Importance: 0.0
# Variable: swim                 Importance: 0.0
# Variable: swimming             Importance: 0.0
# Variable: swing                Importance: 0.0
# Variable: sx2ukqau             Importance: 0.0
# Variable: sxsw                 Importance: 0.0
# Variable: sydney               Importance: 0.0
# Variable: sylviadawkins        Importance: 0.0
# Variable: symbol               Importance: 0.0
# Variable: symptoms             Importance: 0.0
# Variable: syracuse             Importance: 0.0
# Variable: system               Importance: 0.0
# Variable: systems              Importance: 0.0
# Variable: sza                  Importance: 0.0
# Variable: sábado               Importance: 0.0
# Variable: sándor               Importance: 0.0
# Variable: são                  Importance: 0.0
# Variable: sè                   Importance: 0.0
# Variable: sé                   Importance: 0.0
# Variable: sì                   Importance: 0.0
# Variable: sò                   Importance: 0.0
# Variable: só                   Importance: 0.0
# Variable: t_porter_4           Importance: 0.0
# Variable: t_t                  Importance: 0.0
# Variable: ta                   Importance: 0.0
# Variable: table                Importance: 0.0
# Variable: tablet               Importance: 0.0
# Variable: tace                 Importance: 0.0
# Variable: tacere               Importance: 0.0
# Variable: tacito               Importance: 0.0
# Variable: taco                 Importance: 0.0
# Variable: tacos                Importance: 0.0
# Variable: tacticaldriving      Importance: 0.0
# Variable: tadi                 Importance: 0.0
# Variable: tag                  Importance: 0.0
# Variable: tagli                Importance: 0.0
# Variable: taglia               Importance: 0.0
# Variable: tagliata             Importance: 0.0
# Variable: tagliatelle          Importance: 0.0
# Variable: taglio               Importance: 0.0
# Variable: tagore               Importance: 0.0
# Variable: tah                  Importance: 0.0
# Variable: tahoe                Importance: 0.0
# Variable: tailfloof            Importance: 0.0
# Variable: taipei               Importance: 0.0
# Variable: taiwan               Importance: 0.0
# Variable: tak                  Importance: 0.0
# Variable: take                 Importance: 0.0
# Variable: takecare             Importance: 0.0
# Variable: taken                Importance: 0.0
# Variable: takes                Importance: 0.0
# Variable: taking               Importance: 0.0
# Variable: tal                  Importance: 0.0
# Variable: talaga               Importance: 0.0
# Variable: tale                 Importance: 0.0
# Variable: talent               Importance: 0.0
# Variable: talented             Importance: 0.0
# Variable: talento              Importance: 0.0
# Variable: talk                 Importance: 0.0
# Variable: talked               Importance: 0.0
# Variable: talkin               Importance: 0.0
# Variable: talking              Importance: 0.0
# Variable: talks                Importance: 0.0
# Variable: tall                 Importance: 0.0
# Variable: talm                 Importance: 0.0
# Variable: talmente             Importance: 0.0
# Variable: talmud               Importance: 0.0
# Variable: talvez               Importance: 0.0
# Variable: talvolta             Importance: 0.0
# Variable: tam                  Importance: 0.0
# Variable: también              Importance: 0.0
# Variable: também               Importance: 0.0
# Variable: tampa                Importance: 0.0
# Variable: tan                  Importance: 0.0
# Variable: tang                 Importance: 0.0
# Variable: tangina              Importance: 0.0
# Variable: tank                 Importance: 0.0
# Variable: tanning              Importance: 0.0
# Variable: tans                 Importance: 0.0
# Variable: tanta                Importance: 0.0
# Variable: tante                Importance: 0.0
# Variable: tanti                Importance: 0.0
# Variable: tanto                Importance: 0.0
# Variable: tantomeno            Importance: 0.0
# Variable: tantos               Importance: 0.0
# Variable: tao                  Importance: 0.0
# Variable: taong                Importance: 0.0
# Variable: tape                 Importance: 0.0
# Variable: tapi                 Importance: 0.0
# Variable: tapos                Importance: 0.0
# Variable: tappo                Importance: 0.0
# Variable: tara_elise           Importance: 0.0
# Variable: tarde                Importance: 0.0
# Variable: tardi                Importance: 0.0
# Variable: target               Importance: 0.0
# Variable: taricc               Importance: 0.0
# Variable: tas                  Importance: 0.0
# Variable: tasca                Importance: 0.0
# Variable: tasche               Importance: 0.0
# Variable: task                 Importance: 0.0
# Variable: tasse                Importance: 0.0
# Variable: taste                Importance: 0.0
# Variable: tasto                Importance: 0.0
# Variable: tattoo               Importance: 0.0
# Variable: tattoos              Importance: 0.0
# Variable: tatuaggi             Importance: 0.0
# Variable: tatuato              Importance: 0.0
# Variable: tau                  Importance: 0.0
# Variable: taught               Importance: 0.0
# Variable: tava                 Importance: 0.0
# Variable: tavernello           Importance: 0.0
# Variable: tavola               Importance: 0.0
# Variable: tavoletta            Importance: 0.0
# Variable: tavolo               Importance: 0.0
# Variable: tax                  Importance: 0.0
# Variable: taxi                 Importance: 0.0
# Variable: taylor               Importance: 0.0
# Variable: taylorswift13        Importance: 0.0
# Variable: tayo                 Importance: 0.0
# Variable: tazza                Importance: 0.0
# Variable: tbh                  Importance: 0.0
# Variable: tbm                  Importance: 0.0
# Variable: tbt                  Importance: 0.0
# Variable: tcot                 Importance: 0.0
# Variable: tcu                  Importance: 0.0
# Variable: td                   Importance: 0.0
# Variable: tde                  Importance: 0.0
# Variable: tds                  Importance: 0.0
# Variable: te                   Importance: 0.0
# Variable: tea                  Importance: 0.0
# Variable: teach                Importance: 0.0
# Variable: teacher              Importance: 0.0
# Variable: teachers             Importance: 0.0
# Variable: teaching             Importance: 0.0
# Variable: team                 Importance: 0.0
# Variable: teamfollowback       Importance: 0.0
# Variable: teams                Importance: 0.0
# Variable: tear                 Importance: 0.0
# Variable: tears                Importance: 0.0
# Variable: teaser               Importance: 0.0
# Variable: teatro               Importance: 0.0
# Variable: tech                 Importance: 0.0
# Variable: technologies         Importance: 0.0
# Variable: technology           Importance: 0.0
# Variable: ted                  Importance: 0.0
# Variable: tedesca              Importance: 0.0
# Variable: tedeschi             Importance: 0.0
# Variable: tedesco              Importance: 0.0
# Variable: tedofficialpage      Importance: 0.0
# Variable: teee                 Importance: 0.0
# Variable: teen                 Importance: 0.0
# Variable: teens                Importance: 0.0
# Variable: teeth                Importance: 0.0
# Variable: tegen                Importance: 0.0
# Variable: tel                  Importance: 0.0
# Variable: telecomando          Importance: 0.0
# Variable: telefona             Importance: 0.0
# Variable: telefonano           Importance: 0.0
# Variable: telefonata           Importance: 0.0
# Variable: telefonico           Importance: 0.0
# Variable: telefono             Importance: 0.0
# Variable: telegiornale         Importance: 0.0
# Variable: telepatia            Importance: 0.0
# Variable: television           Importance: 0.0
# Variable: tell                 Importance: 0.0
# Variable: tellin               Importance: 0.0
# Variable: telling              Importance: 0.0
# Variable: tells                Importance: 0.0
# Variable: telstra              Importance: 0.0
# Variable: tem                  Importance: 0.0
# Variable: tema                 Importance: 0.0
# Variable: teme                 Importance: 0.0
# Variable: temere               Importance: 0.0
# Variable: tempesta             Importance: 0.0
# Variable: tempeste             Importance: 0.0
# Variable: tempi                Importance: 0.0
# Variable: temple               Importance: 0.0
# Variable: tempo                Importance: 0.0
# Variable: temprano             Importance: 0.0
# Variable: temsutulaimsong      Importance: 0.0
# Variable: ten                  Importance: 0.0
# Variable: tend                 Importance: 0.0
# Variable: tende                Importance: 0.0
# Variable: tenendoli            Importance: 0.0
# Variable: tener                Importance: 0.0
# Variable: tenere               Importance: 0.0
# Variable: tenerla              Importance: 0.0
# Variable: tenersi              Importance: 0.0
# Variable: tenete               Importance: 0.0
# Variable: tengo                Importance: 0.0
# Variable: tengono              Importance: 0.0
# Variable: tenho                Importance: 0.0
# Variable: tenia                Importance: 0.0
# Variable: tennessee            Importance: 0.0
# Variable: tennis               Importance: 0.0
# Variable: tensione             Importance: 0.0
# Variable: tenta                Importance: 0.0
# Variable: tentando             Importance: 0.0
# Variable: tentang              Importance: 0.0
# Variable: tentare              Importance: 0.0
# Variable: tentativi            Importance: 0.0
# Variable: tentativo            Importance: 0.0
# Variable: ter                  Importance: 0.0
# Variable: teresa               Importance: 0.0
# Variable: tergiversare         Importance: 0.0
# Variable: term                 Importance: 0.0
# Variable: termina              Importance: 0.0
# Variable: termine              Importance: 0.0
# Variable: termini              Importance: 0.0
# Variable: terms                Importance: 0.0
# Variable: ternyata             Importance: 0.0
# Variable: terra                Importance: 0.0
# Variable: terrei               Importance: 0.0
# Variable: terremoto            Importance: 0.0
# Variable: terribile            Importance: 0.0
# Variable: terrible             Importance: 0.0
# Variable: terricoulthard       Importance: 0.0
# Variable: terrified            Importance: 0.0
# Variable: terrorists           Importance: 0.0
# Variable: terry                Importance: 0.0
# Variable: terus                Importance: 0.0
# Variable: terza                Importance: 0.0
# Variable: terzo                Importance: 0.0
# Variable: tesi                 Importance: 0.0
# Variable: tesla                Importance: 0.0
# Variable: tesoro               Importance: 0.0
# Variable: tessera              Importance: 0.0
# Variable: test                 Importance: 0.0
# Variable: testa                Importance: 0.0
# Variable: teste                Importance: 0.0
# Variable: testimoni            Importance: 0.0
# Variable: testing              Importance: 0.0
# Variable: tests                Importance: 0.0
# Variable: tetap                Importance: 0.0
# Variable: tette                Importance: 0.0
# Variable: teve                 Importance: 0.0
# Variable: texas                Importance: 0.0
# Variable: text                 Importance: 0.0
# Variable: texted               Importance: 0.0
# Variable: texting              Importance: 0.0
# Variable: texts                Importance: 0.0
# Variable: tf                   Importance: 0.0
# Variable: tfb                  Importance: 0.0
# Variable: tg                   Importance: 0.0
# Variable: tgif                 Importance: 0.0
# Variable: th                   Importance: 0.0
# Variable: tha                  Importance: 0.0
# Variable: thami                Importance: 0.0
# Variable: thamikins_           Importance: 0.0
# Variable: than                 Importance: 0.0
# Variable: thank                Importance: 0.0
# Variable: thankful             Importance: 0.0
# Variable: thanks               Importance: 0.0
# Variable: thanksgiving         Importance: 0.0
# Variable: thanx                Importance: 0.0
# Variable: that                 Importance: 0.0
# Variable: thatcher             Importance: 0.0
# Variable: thats                Importance: 0.0
# Variable: thauane_             Importance: 0.0
# Variable: the                  Importance: 0.0
# Variable: the_ice_drackal      Importance: 0.0
# Variable: theater              Importance: 0.0
# Variable: theatre              Importance: 0.0
# Variable: thedailybeast        Importance: 0.0
# Variable: thedjlist            Importance: 0.0
# Variable: thefirstpillar       Importance: 0.0
# Variable: thefunnyteens        Importance: 0.0
# Variable: theinterview         Importance: 0.0
# Variable: their                Importance: 0.0
# Variable: thekatybug           Importance: 0.0
# Variable: thelmarie            Importance: 0.0
# Variable: them                 Importance: 0.0
# Variable: themacmommy          Importance: 0.0
# Variable: theme                Importance: 0.0
# Variable: themselves           Importance: 0.0
# Variable: then                 Importance: 0.0
# Variable: theodore             Importance: 0.0
# Variable: theory               Importance: 0.0
# Variable: thephilipbrown       Importance: 0.0
# Variable: therapy              Importance: 0.0
# Variable: there                Importance: 0.0
# Variable: therefore            Importance: 0.0
# Variable: theres               Importance: 0.0
# Variable: these                Importance: 0.0
# Variable: thetweetofgod        Importance: 0.0
# Variable: thevampsband         Importance: 0.0
# Variable: thevampsbrad         Importance: 0.0
# Variable: thevampsjames        Importance: 0.0
# Variable: thevishalrishi       Importance: 0.0
# Variable: thewawg              Importance: 0.0
# Variable: thewisdom_           Importance: 0.0
# Variable: they                 Importance: 0.0
# Variable: thick                Importance: 0.0
# Variable: thickgurl_maecy      Importance: 0.0
# Variable: thin                 Importance: 0.0
# Variable: thing                Importance: 0.0
# Variable: things               Importance: 0.0
# Variable: think                Importance: 0.0
# Variable: thinkin              Importance: 0.0
# Variable: thinking             Importance: 0.0
# Variable: thinkprogress        Importance: 0.0
# Variable: thinks               Importance: 0.0
# Variable: third                Importance: 0.0
# Variable: thirsty              Importance: 0.0
# Variable: this                 Importance: 0.0
# Variable: tho                  Importance: 0.0
# Variable: thomas               Importance: 0.0
# Variable: thoreau              Importance: 0.0
# Variable: those                Importance: 0.0
# Variable: thou                 Importance: 0.0
# Variable: though               Importance: 0.0
# Variable: thought              Importance: 0.0
# Variable: thoughts             Importance: 0.0
# Variable: thousand             Importance: 0.0
# Variable: thousands            Importance: 0.0

# %% [markdown]
# The top 5 English words that are important for the model in determining whether a tweet is from a bot or not, according to our model:
#     1. Corporate
#     2. Little
#     3. Patch
#     4. Further
#     5. Semi

# %% [markdown]
# However, this method of tf-idf analysis seems a little problematic because
# most words still have an extremely low score. Perhaps Naive Bayes is better for this model here.

# %%
# Model #1: Unmodified model 

from sklearn.model_selection import train_test_split
import sklearn.naive_bayes

#1. Initialize a vectorizer with min_df of 0
vectorizer = CountVectorizer(min_df=7)

#2. Create a new Multinomial classifier model with trial alpha
model = sklearn.naive_bayes.MultinomialNB(alpha=1)

#3. Fit the vectorizer to get all of the quotes into the appropriate format
vectorizer.fit_transform(all_tweets.text)

#4. Make X, y for training sets 
X, y = make_xy(all_tweets, vectorizer)

# %%
#5. Fit the model to the transformed quotes
model.fit(X, y)

#5.5 Transform new section into an appropriate array?

#6. Transform the new quote into appropriate form, an array that's basically
#a checklist of all words currently in it.
#new_quote = vectorizer.transform(a_quote)

test_cut = test_cut.dropna()
testX = vectorizer.transform(test_cut.text)
testX = testX.tocsc()
testy = (test_cut['origin_x'] == 'real').values.astype(np.int)

#7. Make a prediction on the new quote based on the fitted, transformed quote 
#base that we've been working on.
model.score(testX, testy)
# Out:
# 0.7822318526543879

# %%
words = np.array(vectorizer.get_feature_names())

x = np.eye(testX.shape[1])
probs = model.predict_log_proba(x)[:, 0]
ind = np.argsort(probs)

good_words = words[ind[:20]]
bad_words = words[ind[-20:]]

good_prob = probs[ind[:20]]
bad_prob = probs[ind[-20:]]

#table = pd.DataFrame()

print("Real words\t     P(real | fake)")
for w, p in zip(good_words, good_prob):
    print("{:>20}".format(w), "{:.2f}".format(1 - np.exp(p)))
    #table.append("{:>20}".format(w), "{:.2f}".format(1 - np.exp(p)))
    
print("Fake words\t     P(real | fake)")
for w, p in zip(bad_words, bad_prob):
    print("{:>20}".format(w), "{:.2f}".format(1 - np.exp(p)))
# Out:
# Real words	     P(real | fake)
#              rangers 1.00
#           myvaranasi 1.00
#         explicitlyn_ 1.00
#                 grum 0.99
#              dodgers 0.99
#              ventura 0.99
#                   पर 0.99
#                casey 0.99
#           willow_fox 0.99
#               tucson 0.99
#                   कर 0.99
#         uptownhooker 0.99
#         narendramodi 0.99
#              kiim995 0.99
#                capey 0.99
#       susanspurgeon1 0.99
#           rav_bunneh 0.99
#      carolineheldman 0.99
#             lul_dope 0.99
#          shotsofblue 0.99
# Fake words	     P(real | fake)
#                  sei 0.00
#              persone 0.00
#               perché 0.00
#                amore 0.00
#                tutti 0.00
#          accaddeoggi 0.00
#          staseraintv 0.00
#                 fare 0.00
#                 cosa 0.00
#                 uomo 0.00
#               sempre 0.00
#                anche 0.00
#               essere 0.00
#                   ci 0.00
#                  gli 0.00
#                  più 0.00
#               quando 0.00
#                   il 0.00
#                 sono 0.00
#                  che 0.00

# %%
#Prepare Tfidf score dictionary of training set

idf = tfidf.idf_
dic = dict(zip(tfidf.get_feature_names(), idf))
print(dic)
# Out:
# {'00': 7.1737444363671905, '000': 7.641084948193442, '01': 9.09333727710513, '02': 8.965503905595245, '03': 8.629031668974033, '04': 8.090035168241346, '05': 7.907713611447391, '06': 8.888542864459117, '07': 9.188647456909456, '08': 9.476329529361236, '09': 9.09333727710513, '10': 5.672634400818718, '100': 7.140954613544199, '1000': 7.866891616927136, '101': 9.411791008223664, '103': 9.786484457665075, '10pm': 9.786484457665075, '10th': 9.987155153127226, '11': 6.804482376922986, '113': 9.786484457665075, '12': 6.88107482240437, '120': 9.987155153127226, '13': 7.465880859168352, '130': 9.881794637469401, '13th': 10.10493818878361, '14': 7.530419380305923, '140': 9.545322400848187, '15': 6.233737177875719, '150': 9.881794637469401, '1582': 10.10493818878361, '16': 7.65178023731019, '160': 9.987155153127226, '16th': 9.881794637469401, '17': 7.840574308609762, '18': 7.718471611808862, '182': 10.238469581408133, '1861': 9.987155153127226, '1864': 10.238469581408133, '19': 8.009992460567808, '1912': 10.238469581408133, '1918': 10.10493818878361, '1919': 10.238469581408133, '1929': 9.786484457665075, '1933': 10.238469581408133, '1935': 9.786484457665075, '1938': 10.10493818878361, '1941': 10.10493818878361, '1942': 10.10493818878361, '1943': 10.238469581408133, '1944': 9.881794637469401, '1945': 10.10493818878361, '1949': 10.10493818878361, '1957': 10.10493818878361, '1960': 9.786484457665075, '1962': 10.10493818878361, '1964': 10.238469581408133, '1967': 9.61943037300191, '1968': 9.786484457665075, '1969': 10.238469581408133, '1970': 9.786484457665075, '1971': 10.238469581408133, '1972': 10.10493818878361, '1976': 9.987155153127226, '1977': 10.238469581408133, '1980': 9.786484457665075, '1984': 9.987155153127226, '1985': 10.10493818878361, '1987': 9.987155153127226, '1989': 10.238469581408133, '1990': 9.699473080675446, '1991': 9.786484457665075, '1992': 10.238469581408133, '1993': 10.10493818878361, '1994': 9.987155153127226, '1995': 10.238469581408133, '1998': 9.881794637469401, '1999': 9.881794637469401, '19th': 10.10493818878361, '1d': 9.881794637469401, '1d_forcaity': 9.699473080675446, '1dupdatesonline': 10.238469581408133, '1st': 8.090035168241346, '20': 6.542472659525332, '200': 8.49550027634951, '2000': 8.334232128753388, '2001': 9.476329529361236, '2002': 10.10493818878361, '2003': 9.881794637469401, '2004': 9.61943037300191, '2005': 9.545322400848187, '2006': 9.61943037300191, '2007': 9.239940751297006, '2008': 10.238469581408133, '2009': 8.965503905595245, '2010': 8.687872168996964, '2011': 7.950273225866186, '2012': 7.730032434209939, '2013': 7.465880859168352, '2014': 7.474849529151112, '2015': 7.324567326101774, '2016': 9.476329529361236, '2020': 10.10493818878361, '21': 5.606518372742399, '22': 8.041245004071914, '23': 8.106842286557725, '24': 7.559406917179175, '240': 10.10493818878361, '247': 10.10493818878361, '25': 7.579209544475355, '250': 9.545322400848187, '26': 8.600860792007335, '27': 8.214087816911324, '28': 8.057245345418355, '29': 8.214087816911324, '2nd': 8.629031668974033, '2x': 10.238469581408133, '30': 6.563978864746296, '300': 8.78318234880129, '30pm': 10.238469581408133, '31': 8.600860792007335, '32': 8.600860792007335, '33': 8.965503905595245, '333': 10.10493818878361, '34': 9.188647456909456, '35': 8.750392525978299, '353': 10.238469581408133, '36': 9.239940751297006, '360': 9.699473080675446, '365': 9.545322400848187, '37': 9.239940751297006, '38': 9.188647456909456, '39': 9.35116638640723, '3a': 10.238469581408133, '3d': 9.188647456909456, '3g': 9.987155153127226, '3mesi': 9.786484457665075, '3pm': 10.238469581408133, '3rd': 9.239940751297006, '40': 7.777660483199193, '400': 9.0063259001155, '41': 9.61943037300191, '42': 8.965503905595245, '420': 10.10493818878361, '43': 9.29400797256728, '432': 10.238469581408133, '44': 9.61943037300191, '45': 7.827670903773854, '45pm': 10.238469581408133, '46': 9.188647456909456, '47': 8.852175220288242, '47enne': 9.476329529361236, '48': 9.0063259001155, '49 ...

# %%
#Make categories out of tf-idf scores 
tfidf_buckets = []

for key, value in dic.items():

    tfidf_buckets.append(value)

# %%
#Plot distribution plot

sns.distplot(tfidf_buckets)
plt.xlabel('Tf-Idf score')
plt.ylabel('Count')
plt.title('Dist of TfIdf scores')
# Out:
# C:\Users\cct51\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Dist of TfIdf scores')
